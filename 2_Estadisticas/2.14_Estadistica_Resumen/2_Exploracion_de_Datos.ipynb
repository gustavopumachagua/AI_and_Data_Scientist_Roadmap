# %% [markdown]
# | **Inicio** | **atrás 1** | **Siguiente 3** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./1_Introduccion_a_la_Estadistica.ipynb)| [⏩](./3_Visualizacion_de_Datos.ipynb)|

# %% [markdown]
# # **2. Exploración de Datos**

# %% [markdown]
# ## **Medidas de Tendencia Central**

# %% [markdown]
# ### **Media, mediana y moda**

# %% [markdown]
# La media, mediana y moda son medidas de tendencia central utilizadas en estadísticas descriptivas para resumir conjuntos de datos. Aquí hay una explicación detallada con ejemplos y gráficos en Python:
#
# **1. Media:**
#
# La media es el promedio de un conjunto de datos y se calcula sumando todos los valores y dividiendo por el número total de observaciones.
#
# $\text{Media} = \frac{\sum_{i=1}^{n} X_i}{n}$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Crear datos para ejemplo
datos = np.random.normal(loc=50, scale=10, size=100)

# Calcular la media
media = np.mean(datos)

# Gráfico de histograma con personalizaciones
plt.figure(figsize=(10, 6))
plt.hist(datos, bins=20, color='skyblue', edgecolor='black')

# Línea vertical para la media
plt.axvline(media, color='red', linestyle='dashed', linewidth=2, label=f'Media = {media:.2f}')

# Título y etiquetas del eje
plt.title('Histograma con Media', fontsize=16)
plt.xlabel('Datos', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)

# Leyenda
plt.legend()

# Mostrar la gráfica
plt.show()

# %% [markdown]
# **2. Mediana:**
#
# La mediana es el valor que separa la mitad superior e inferior de un conjunto de datos ordenados. Para encontrar la mediana, primero ordenamos los datos y luego seleccionamos el valor en el medio.

# %% [markdown]
# La mediana es el valor que se encuentra en el centro de un conjunto de datos ordenados, de manera que divide el conjunto en dos partes iguales. La fórmula para calcular la mediana depende de si la cantidad de datos $(n)$ en el conjunto es impar o par.
#
# 1. **Para una cantidad impar de datos $(n)$ impar:**
#
#    La mediana $(M)$ es simplemente el valor que ocupa la posición central en el conjunto ordenado. Si los datos están ordenados de menor a mayor, la posición de la mediana es $(\frac{n + 1}{2})$.
#
#    $M = \text{valor en la posición } \frac{n + 1}{2}$
#
# 2. **Para una cantidad par de datos $(n)$ par:**
#
#    En este caso, la mediana es el promedio de los dos valores centrales. Si los datos están ordenados de menor a mayor, las posiciones de los valores centrales son $(\frac{n}{2})$ y $(\frac{n}{2} + 1)$.
#
#    $M = \frac{\text{valor en la posición } \frac{n}{2} + \text{valor en la posición } \frac{n}{2} + 1}{2}$
#
# En resumen, la mediana es una medida de tendencia central que no se ve afectada por valores extremos (a diferencia del promedio). Si la cantidad de datos es impar, la mediana es el valor central; si la cantidad es par, es el promedio de los dos valores centrales.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Crear datos para ejemplo
datos = np.random.normal(loc=50, scale=10, size=100)

# Calcular la mediana
mediana = np.median(datos)

# Gráfico de histograma con personalizaciones
plt.figure(figsize=(10, 6))
plt.hist(datos, bins=20, color='skyblue', edgecolor='black')

# Línea vertical para la mediana
plt.axvline(mediana, color='green', linestyle='dashed', linewidth=2, label=f'Mediana = {mediana:.2f}')

# Título y etiquetas del eje
plt.title('Histograma con Mediana', fontsize=16)
plt.xlabel('Datos', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)

# Leyenda
plt.legend()

# Añadir una nota sobre la mediana
plt.text(mediana + 2, 10, f'Mediana = {mediana:.2f}', color='green', fontsize=12, bbox=dict(facecolor='white', alpha=0.8))

# Mostrar la gráfica
plt.show()

# %% [markdown]
# **3. Moda:**
#
# La moda es el valor que aparece con mayor frecuencia en un conjunto de datos. Puede haber una moda (datos unimodales), dos modas (datos bimodales), o más.

# %% [markdown]
# Estos ejemplos utilizan datos aleatorios generados con distribución normal, y los gráficos muestran la posición de la media, mediana y moda en el contexto de un histograma. Estas medidas proporcionan información sobre la tendencia central de los datos.

# %% [markdown]
# ### **Interpretación y uso en diferentes contextos**

# %% [markdown]
# **1. Media (Promedio):**
#
# La media es el promedio aritmético de un conjunto de datos y se calcula sumando todos los valores y dividiendo por el número de observaciones.
#
# $\text{Media} = \frac{\sum_{i=1}^{n} x_i}{n}$
#
# **Interpretación:**
#
# La media representa el "centro de masa" del conjunto de datos y es sensible a los valores atípicos (outliers).
#
# **Código Python con Gráfico Personalizado:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Crear datos para ejemplo
datos = np.random.normal(loc=50, scale=10, size=100)

# Calcular la media
media = np.mean(datos)

# Gráfico de histograma con la media
plt.figure(figsize=(10, 6))
plt.hist(datos, bins=20, color='skyblue', edgecolor='black')
plt.axvline(media, color='red', linestyle='dashed', linewidth=2, label=f'Media = {media:.2f}')
plt.title('Histograma con Media')
plt.xlabel('Datos')
plt.ylabel('Frecuencia')
plt.legend()
plt.show()

# %% [markdown]
# Este gráfico muestra un histograma con una línea punteada que representa la media.
#
# **2. Mediana:**
#
# La mediana es el valor que divide el conjunto de datos ordenado en dos partes iguales.
#
# **Interpretación:**
#
# La mediana es menos sensible a los valores atípicos y proporciona información sobre la ubicación central real del conjunto de datos.
#
# **Código Python con Gráfico Personalizado:**

# %%
# Calcular la mediana
mediana = np.median(datos)

# Gráfico de histograma con la mediana
plt.figure(figsize=(10, 6))
plt.hist(datos, bins=20, color='skyblue', edgecolor='black')
plt.axvline(mediana, color='green', linestyle='dashed', linewidth=2, label=f'Mediana = {mediana:.2f}')
plt.title('Histograma con Mediana')
plt.xlabel('Datos')
plt.ylabel('Frecuencia')
plt.legend()
plt.show()

# %% [markdown]
# Este gráfico muestra un histograma con una línea punteada que representa la mediana.
#
# **3. Moda:**
#
# La moda es el valor que ocurre con mayor frecuencia en el conjunto de datos.
#
# **Interpretación:**
#
# La moda es útil para identificar los valores más comunes en un conjunto de datos.

# %% [markdown]
# ## **Medidas de Dispersión**

# %% [markdown]
# ### **Rango, desviación estándar y varianza**

# %% [markdown]
# **Rango:**
#
# El rango en estadísticas es la diferencia entre el valor máximo y el valor mínimo en un conjunto de datos. Proporciona una medida de la dispersión o amplitud del conjunto. Matemáticamente, se calcula como $( R = \text{valor máximo} - \text{valor mínimo} )$.
#
# Voy a generar datos de ejemplo y mostrar el cálculo del rango con un gráfico:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos de ejemplo
datos = np.random.randint(0, 100, size=50)

# Calcular el rango
rango = np.max(datos) - np.min(datos)

# Gráfico de los datos
plt.figure(figsize=(10, 6))
plt.scatter(range(len(datos)), datos, color='blue', label='Datos')
plt.title('Datos de Ejemplo con Rango')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.axhline(y=np.max(datos), color='red', linestyle='--', label='Valor Máximo')
plt.axhline(y=np.min(datos), color='green', linestyle='--', label='Valor Mínimo')
plt.legend()
plt.show()

print(f"El rango de los datos es: {rango}")
# Out:
# El rango de los datos es: 93

# %% [markdown]
# **Desviación estándar y Varianza:**
#
# La varianza y la desviación estándar son medidas de dispersión que indican cuánto se alejan los valores individuales del centro del conjunto de datos.
#
# La varianza $(S^2)$ es el promedio de las diferencias al cuadrado entre cada valor y la media del conjunto. La desviación estándar $(S)$ es simplemente la raíz cuadrada de la varianza $(S = \sqrt{S^2})$.
#
# Ahora, generemos datos de ejemplo, calculemos la varianza y la desviación estándar, y creemos un gráfico para visualizar la dispersión:

# %%
# Generar datos de ejemplo
datos = np.random.normal(loc=50, scale=10, size=100)

# Calcular la varianza y desviación estándar
varianza = np.var(datos)
desviacion_estandar = np.std(datos)

# Gráfico de histograma para visualizar la dispersión
plt.figure(figsize=(10, 6))
plt.hist(datos, bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma con Desviación Estándar y Varianza')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.axvline(x=np.mean(datos), color='red', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(x=np.mean(datos) + desviacion_estandar, color='orange', linestyle='dashed', linewidth=2, label='Desviación Estándar')
plt.axvline(x=np.mean(datos) - desviacion_estandar, color='orange', linestyle='dashed', linewidth=2)
plt.legend()
plt.show()

print(f"La varianza de los datos es: {varianza}")
print(f"La desviación estándar de los datos es: {desviacion_estandar}")
# Out:
# La varianza de los datos es: 97.72699412610945
# La desviación estándar de los datos es: 9.88569644112692

# %% [markdown]
# En este ejemplo, se generaron datos normalmente distribuidos con una media de 50 y una desviación estándar de 10. El gráfico muestra la distribución de los datos junto con la media y la desviación estándar.

# %% [markdown]
# ### **Interpretación de la dispersión de datos**

# %% [markdown]
# La dispersión en estadísticas se refiere a la extensión o propagación de los valores en un conjunto de datos. Las medidas de dispersión proporcionan información sobre cuán dispersos o concentrados están los valores en torno a una medida central, como la media. Las principales medidas de dispersión son el rango, la varianza y la desviación estándar. Aquí, explicaré la interpretación de estas medidas con ejemplos y gráficos personalizados en Python.
#
# **1. Rango:**
#
# El rango mide la amplitud total de los datos, es decir, la diferencia entre el valor máximo y el valor mínimo. Un rango grande indica una mayor dispersión.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos de ejemplo
datos = np.random.randint(0, 100, size=50)

# Calcular el rango
rango = np.max(datos) - np.min(datos)

# Gráfico de los datos
plt.figure(figsize=(10, 6))
plt.scatter(range(len(datos)), datos, color='blue', label='Datos')
plt.title('Datos de Ejemplo con Rango')
plt.xlabel('Índice')
plt.ylabel('Valor')
plt.axhline(y=np.max(datos), color='red', linestyle='--', label='Valor Máximo')
plt.axhline(y=np.min(datos), color='green', linestyle='--', label='Valor Mínimo')
plt.legend()
plt.show()

print(f"El rango de los datos es: {rango}")
# Out:
# El rango de los datos es: 96

# %% [markdown]
# En este ejemplo, el gráfico muestra la dispersión de los datos y cómo el rango se calcula a partir del valor máximo y mínimo.
#
# **2. Varianza y Desviación Estándar:**
#
# La varianza y la desviación estándar miden cuán dispersos están los datos en relación con la media. Una varianza grande indica mayor dispersión.

# %%
# Generar datos de ejemplo
datos = np.random.normal(loc=50, scale=10, size=100)

# Calcular la varianza y desviación estándar
varianza = np.var(datos)
desviacion_estandar = np.std(datos)

# Gráfico de histograma para visualizar la dispersión
plt.figure(figsize=(10, 6))
plt.hist(datos, bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma con Desviación Estándar y Varianza')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.axvline(x=np.mean(datos), color='red', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(x=np.mean(datos) + desviacion_estandar, color='orange', linestyle='dashed', linewidth=2, label='Desviación Estándar')
plt.axvline(x=np.mean(datos) - desviacion_estandar, color='orange', linestyle='dashed', linewidth=2)
plt.legend()
plt.show()

print(f"La varianza de los datos es: {varianza}")
print(f"La desviación estándar de los datos es: {desviacion_estandar}")
# Out:
# La varianza de los datos es: 111.21496287097189
# La desviación estándar de los datos es: 10.545850504865498

# %% [markdown]
# Este gráfico muestra cómo la varianza y la desviación estándar describen la dispersión de los datos alrededor de la media. La línea roja representa la media, y las líneas naranjas indican la desviación estándar. Cuanto mayor sea la desviación estándar, mayor será la dispersión de los datos.

# %% [markdown]
# | **Inicio** | **atrás 1** | **Siguiente 3** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./1_Introduccion_a_la_Estadistica.ipynb)| [⏩](./3_Visualizacion_de_Datos.ipynb)|
