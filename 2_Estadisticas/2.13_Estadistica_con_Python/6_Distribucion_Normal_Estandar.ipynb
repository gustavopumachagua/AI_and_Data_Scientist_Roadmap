# %% [markdown]
# | **Inicio** | **atrás 5** | **Siguiente 7** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./5_Intervalos_de_Confianza.ipynb)| [⏩](./7_la_Matriz_de_Covarianza.ipynb)|

# %% [markdown]
# # **6. De dónde vienen las Puntuaciones Z y la Distribución Normal Estándar: Un ejemplo con Python**

# %% [markdown]
# ## **Introducción**

# %% [markdown]
# Las Puntuaciones Z y la Distribución Normal Estándar están estrechamente relacionadas y son fundamentales en la estadística. Ambos conceptos se utilizan para estandarizar y comparar datos en una escala común, lo que facilita el análisis y la toma de decisiones basadas en los datos.
#
# **Puntuaciones Z (Z-Scores):**
#
# Las Puntuaciones Z, también conocidas como Z-Scores, son una medida estadística que nos permite cuantificar cuántas desviaciones estándar se encuentra un valor particular con respecto a la media de una distribución. Esto significa que los Z-Scores nos permiten entender qué tan lejos o cerca está un valor de la media en términos de unidades de desviación estándar.
#
# El cálculo de un Z-Score para un dato (x) se realiza utilizando la siguiente fórmula:
#
# $Z = (x - media) / desviación estándar$
#
# Donde:
#
# * **x** es el valor individual de la muestra.
#
# * media es la media de la muestra.
#
# * desviación estándar es la desviación estándar de la muestra.
#
# Un Z-Score positivo indica que el valor se encuentra por encima de la media, mientras que un Z-Score negativo indica que el valor está por debajo de la media. Un Z-Score de 0 significa que el valor es igual a la media.
#
# **Distribución Normal Estándar:**
#
# La Distribución Normal Estándar es una distribución de probabilidad continua con media 0 y desviación estándar 1. Tiene una forma de campana simétrica y es una de las distribuciones más importantes en estadística debido a su amplia aplicabilidad y propiedades matemáticas.
#
# La función de densidad de probabilidad de la Distribución Normal Estándar se define como:
#
#
# $f(x) = (1 / √(2π)) * e^{-x^2/2}$
#
# donde **e** es la base del logaritmo natural y π es pi (aproximadamente 3.14159).
#
# **Ejemplo con Python:**
#
# Vamos a generar un conjunto de datos aleatorios y calcular sus Puntuaciones Z para ilustrar cómo están relacionados con la Distribución Normal Estándar. Utilizaremos Python y las bibliotecas NumPy y Matplotlib para realizar el análisis y la visualización.
#
# **Paso 1: Importar las bibliotecas necesarias**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Paso 2: Generar datos aleatorios**

# %%
np.random.seed(42)  # Fijar la semilla para reproducibilidad
datos = np.random.normal(loc=50, scale=10, size=1000)

# %% [markdown]
# **Paso 3: Calcular la media y desviación estándar de los datos**

# %%
media = np.mean(datos)
desviacion_estandar = np.std(datos)

# %% [markdown]
# **Paso 4: Calcular los Puntuaciones Z para los datos**

# %% [markdown]
# `z_scores = (datos - media) / desviacion_estandar`

# %% [markdown]
# **Paso 5: Graficar el histograma de los datos y la Distribución Normal Estándar**

# %%
# Crear el histograma
plt.hist(datos, bins=30, density=True, alpha=0.7, label='Datos')

# Calcular los valores para la curva de la Distribución Normal Estándar
x = np.linspace(-5, 5, 1000)
y = (1 / np.sqrt(2 * np.pi)) * np.exp(-x**2 / 2)

# Graficar la curva de la Distribución Normal Estándar
plt.plot(x, y, 'r', label='Distribución Normal Estándar')

plt.xlabel('Valores')
plt.ylabel('Densidad de Probabilidad')
plt.title('Histograma y Distribución Normal Estándar')
plt.legend()
plt.show()

# %% [markdown]
# **Resultado:**
#
# En la gráfica resultante, verás un histograma que representa los datos generados aleatoriamente y una curva roja que representa la Distribución Normal Estándar. Observarás que la Distribución Normal Estándar tiene media 0 y desviación estándar 1, y se ajusta bien a la forma del histograma de los datos. Además, puedes notar que los Puntuaciones Z para cada valor de la muestra representan cuántas desviaciones estándar están por encima o por debajo de la media.
#
# Es importante comprender cómo la Distribución Normal Estándar y las Puntuaciones Z están relacionadas, ya que este conocimiento es fundamental para muchos análisis estadísticos, pruebas de hipótesis y cálculos de intervalos de confianza. Nos permiten estandarizar y comparar diferentes conjuntos de datos, lo que facilita la interpretación y el análisis de resultados.

# %% [markdown]
# ## **Distribución Normal**

# %% [markdown]
# La Distribución Normal, también conocida como Distribución Gaussiana, es una de las distribuciones de probabilidad más importantes en estadística y matemáticas. Se caracteriza por ser continua, simétrica y tener una forma de campana. Es ampliamente utilizada en diferentes áreas debido a su capacidad para describir muchos fenómenos naturales y sociales.
#
# **Características de la Distribución Normal:**
#
# 1. **Forma de campana:**
#
#  La curva de la Distribución Normal tiene una forma de campana, con el punto más alto en el centro, que representa la media.
#
# 2. **Simetría:**
#
#  La distribución es simétrica respecto a su media. Esto significa que la mitad izquierda y la mitad derecha de la curva son espejo una de la otra.
#
# 3. **Media, Mediana y Moda son iguales:**
#
#  La media, mediana y moda de una distribución normal coinciden, lo que indica que el centro de la distribución se encuentra en el valor de la media.
#
# 4. **Desviación Estándar:**
#
#  La desviación estándar determina el ancho de la campana. Cuanto mayor sea la desviación estándar, más ancha será la campana.
#
# **Función de Densidad de Probabilidad (PDF) de la Distribución Normal:**
#
# La función de densidad de probabilidad de la Distribución Normal está definida por la siguiente fórmula:

# %% [markdown]
# $f(x) = (1 / (σ * √(2π))) * e^{-((x - μ)^2) / (2σ^2)}$

# %% [markdown]
# donde:
#
# * $x$ es la variable aleatoria.
#
# * $μ$ es la media de la distribución.
#
# * $σ$ es la desviación estándar de la distribución.
#
# * $π$ es el número pi (aproximadamente 3.14159).
#
# * $e$ es la base del logaritmo natural (aproximadamente 2.71828).
#
# **Ejemplo con Python:**
#
# Vamos a utilizar Python y la biblioteca Matplotlib para graficar la función de densidad de probabilidad de la Distribución Normal con diferentes valores de media y desviación estándar.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir los parámetros de la Distribución Normal
media1, desviacion_estandar1 = 0, 1
media2, desviacion_estandar2 = 2, 0.5

# Crear un conjunto de valores en el rango de -5 a 5
x = np.linspace(-5, 5, 1000)

# Calcular la función de densidad de probabilidad para cada parámetro
pdf1 = (1 / (desviacion_estandar1 * np.sqrt(2 * np.pi))) * np.exp(-((x - media1) ** 2) / (2 * desviacion_estandar1 ** 2))
pdf2 = (1 / (desviacion_estandar2 * np.sqrt(2 * np.pi))) * np.exp(-((x - media2) ** 2) / (2 * desviacion_estandar2 ** 2))

# Graficar las funciones de densidad de probabilidad
plt.plot(x, pdf1, label=f'Media = {media1}, Desv. Est. = {desviacion_estandar1}')
plt.plot(x, pdf2, label=f'Media = {media2}, Desv. Est. = {desviacion_estandar2}')

plt.xlabel('Valores')
plt.ylabel('Densidad de Probabilidad')
plt.title('Distribución Normal')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Resultado:**
#
# El código generará una gráfica que muestra dos curvas, cada una representando una Distribución Normal con diferentes valores de media y desviación estándar. Observarás cómo cambia la forma de la campana y el ancho de la distribución para diferentes parámetros.
#
# En el ejemplo, la primera distribución tiene una media de 0 y una desviación estándar de 1, mientras que la segunda distribución tiene una media de 2 y una desviación estándar de 0.5. Puedes experimentar con diferentes valores para observar cómo afectan a la forma de la curva de la Distribución Normal.
#
# La Distribución Normal es ampliamente utilizada en estadística y en el análisis de datos debido a sus propiedades matemáticas y a su aparición frecuente en la naturaleza y en diferentes fenómenos. Es fundamental para muchos métodos estadísticos y es la base para muchos análisis y pruebas hipotéticas.

# %% [markdown]
# ## **Ejemplo con 2 muestras**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir los parámetros de la Distribución Normal para ambas muestras
media1, desviacion_estandar1 = 50, 10
media2, desviacion_estandar2 = 60, 15

# Generar dos conjuntos de datos para las dos muestras
muestra1 = np.random.normal(loc=media1, scale=desviacion_estandar1, size=1000)
muestra2 = np.random.normal(loc=media2, scale=desviacion_estandar2, size=1000)

# Crear un conjunto de valores para la gráfica
x = np.linspace(20, 100, 1000)

# Calcular las funciones de densidad de probabilidad para ambas muestras
pdf1 = (1 / (desviacion_estandar1 * np.sqrt(2 * np.pi))) * np.exp(-((x - media1) ** 2) / (2 * desviacion_estandar1 ** 2))
pdf2 = (1 / (desviacion_estandar2 * np.sqrt(2 * np.pi))) * np.exp(-((x - media2) ** 2) / (2 * desviacion_estandar2 ** 2))

# Configuración del gráfico
plt.figure(figsize=(10, 6))
plt.plot(x, pdf1, label=f'Muestra 1 (Media = {media1}, σ = {desviacion_estandar1})', color='navy', linewidth=2)
plt.plot(x, pdf2, label=f'Muestra 2 (Media = {media2}, σ = {desviacion_estandar2})', color='darkred', linewidth=2)

# Graficar los histogramas de las dos muestras
plt.hist(muestra1, bins=30, alpha=0.5, density=True, color='lightblue', edgecolor='black')
plt.hist(muestra2, bins=30, alpha=0.5, density=True, color='salmon', edgecolor='black')

plt.xlabel('Valores', fontsize=12)
plt.ylabel('Densidad de Probabilidad', fontsize=12)
plt.title('Comparación de Distribuciones Normales', fontsize=14)
plt.legend(loc='upper right')
plt.grid(True)
plt.show()

# %% [markdown]
# **Resultado:**
#
# En la gráfica resultante, verás dos curvas de distribución normal, cada una representando una muestra diferente. También se muestran los histogramas de las dos muestras. Ambas muestras siguen una distribución normal, pero con diferentes medias y desviaciones estándar.
#
# En este ejemplo, la muestra 1 tiene una media de 50 y una desviación estándar de 10, mientras que la muestra 2 tiene una media de 60 y una desviación estándar de 15. Observarás cómo las curvas y los histogramas se ajustan a los parámetros específicos de cada muestra.
#
# Este ejemplo ilustra cómo se pueden comparar visualmente dos muestras utilizando sus distribuciones normales respectivas. También muestra cómo la variación en la media y la desviación estándar afecta la forma de la campana y la dispersión de los datos en cada muestra.

# %% [markdown]
# ## **Distribución Normal Estándar**

# %% [markdown]
# La Distribución Normal Estándar, también conocida como Distribución Normal Z o Distribución Normal Estandarizada, es una distribución de probabilidad especial que tiene una media de 0 y una desviación estándar de 1. Es una forma específica de la Distribución Normal que ha sido estandarizada para que sus valores se encuentren en una escala común.
#
# **Características de la Distribución Normal Estándar:**
#
# 1. **Media igual a 0:** La media de la distribución normal estándar es 0.
#
# 2. **Desviación Estándar igual a 1:** La desviación estándar de la distribución normal estándar es 1.
#
# 3. **Forma de campana:** La curva tiene una forma de campana simétrica, igual que la Distribución Normal.
#
# **Función de Densidad de Probabilidad (PDF) de la Distribución Normal Estándar:**
#
# La función de densidad de probabilidad de la Distribución Normal Estándar se puede expresar matemáticamente como:
#
# ```
# f(x) = (1 / √(2π)) * e^(-x^2/2)
# ```
#
# donde:
#
# - `x` es la variable aleatoria.
#
# - `π` es el número pi (aproximadamente 3.14159).
#
# - `e` es la base del logaritmo natural (aproximadamente 2.71828).
#
# **Gráfica de la Distribución Normal Estándar:**
#
# La gráfica de la Distribución Normal Estándar muestra una curva simétrica alrededor del eje vertical en `x = 0`, que representa la media. La curva tiene un pico en `x = 0` y se extiende hacia ambos lados, tendiendo a cero a medida que se aleja de la media.
#
# **Uso de la Distribución Normal Estándar:**
#
# La Distribución Normal Estándar es de gran utilidad en estadística y análisis de datos debido a que muchos fenómenos naturales y sociales tienden a seguir una distribución normal. Además, esta distribución es fundamental para la estandarización de datos y para realizar cálculos de Puntuaciones Z (Z-Scores) para comparar y analizar diferentes conjuntos de datos.
#
# **Ejemplo con Python:**
#
# Podemos utilizar Python y la biblioteca Matplotlib para graficar la función de densidad de probabilidad de la Distribución Normal Estándar.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Crear un conjunto de valores en el rango de -3 a 3
x = np.linspace(-3, 3, 1000)

# Calcular la función de densidad de probabilidad para la Distribución Normal Estándar
pdf = (1 / np.sqrt(2 * np.pi)) * np.exp(-x**2 / 2)

# Graficar la Distribución Normal Estándar
plt.plot(x, pdf, label='Distribución Normal Estándar')

plt.xlabel('Valores')
plt.ylabel('Densidad de Probabilidad')
plt.title('Distribución Normal Estándar')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Resultado:**
#
# El código generará una gráfica que muestra la curva de la Distribución Normal Estándar, que es simétrica alrededor de la media (0) y tiene una forma de campana. Observarás cómo la curva alcanza su punto máximo en `x = 0` y se extiende hacia ambos lados, tendiendo a cero a medida que se aleja de la media.
#
# La Distribución Normal Estándar es una herramienta poderosa en estadística y análisis de datos, ya que proporciona una base para estandarizar datos y realizar comparaciones significativas entre diferentes conjuntos de datos. También es útil para calcular Puntuaciones Z, lo que nos permite entender cuántas desviaciones estándar se encuentra un valor particular con respecto a la media de una distribución.

# %% [markdown]
# ## **Estandarización de las muestras**

# %% [markdown]
# La estandarización de las muestras, también conocida como normalización de datos o estandarización Z, es un proceso común en estadística que tiene como objetivo transformar los valores de una muestra para que se ajusten a una Distribución Normal Estándar (con media 0 y desviación estándar 1). Esto facilita la comparación y el análisis de datos entre diferentes conjuntos, ya que todos los valores estarán en la misma escala común.
#
# La estandarización se realiza calculando los Z-Scores (Puntuaciones Z) para cada valor en la muestra. Los Z-Scores indican cuántas desviaciones estándar se encuentra un valor específico con respecto a la media de la muestra original. Un Z-Score positivo indica que el valor está por encima de la media, mientras que un Z-Score negativo indica que el valor está por debajo de la media.
#
# El cálculo de los Z-Scores se realiza mediante la siguiente fórmula:
#
# ```
# Z = (x - media) / desviación estándar
# ```
#
# donde:
#
# - `Z` es el Z-Score del valor `x`.
#
# - `x` es el valor individual en la muestra.
#
# - `media` es la media de la muestra original.
#
# - `desviación estándar` es la desviación estándar de la muestra original.
#
# Una vez que se han calculado los Z-Scores para todos los valores de la muestra, los datos se habrán estandarizado, y ahora todos los valores tendrán una media de 0 y una desviación estándar de 1.
#
# **Importancia de la Estandarización:**
#
# La estandarización de las muestras es útil en diversas situaciones, entre las cuales se incluyen:
#
# 1. **Comparación de datos:**
#
#  Permite comparar diferentes conjuntos de datos que tienen unidades de medida diferentes o escalas distintas.
#
# 2. **Análisis de Outliers:**
#
#  Facilita la identificación de valores atípicos (outliers) al resaltar aquellos con Z-Scores extremadamente altos o bajos.
#
# 3. **Normalización de variables:**
#
#  Se usa en algoritmos de aprendizaje automático y análisis multivariante para asegurar que las variables tengan el mismo impacto en el análisis.
#
# **Ejemplo de Estandarización con Python:**
#
# Vamos a realizar un ejemplo de estandarización de una muestra utilizando Python y la biblioteca NumPy.

# %%
import numpy as np

# Datos de la muestra original
muestra_original = np.array([32, 45, 38, 55, 48, 52, 47, 50, 42, 44])

# Calcular la media y desviación estándar de la muestra original
media_original = np.mean(muestra_original)
desviacion_estandar_original = np.std(muestra_original)

# Calcular los Z-Scores para cada valor en la muestra
z_scores = (muestra_original - media_original) / desviacion_estandar_original

# Mostrar la muestra original y los Z-Scores
print("Muestra original:", muestra_original)
print("Z-Scores:", z_scores)
# Out:
# Muestra original: [32 45 38 55 48 52 47 50 42 44]
# Z-Scores: [-2.06680273 -0.04661961 -1.13441052  1.5073674   0.41957649  1.0411713
#   0.26417779  0.7303739  -0.51281571 -0.20201831]

# %% [markdown]
# **Resultado:**
#
# La muestra original será mostrada, así como los Z-Scores para cada valor en la muestra. Los Z-Scores representan cuántas desviaciones estándar están por encima o por debajo de la media para cada valor en la muestra original.
#
# Recuerda que después de la estandarización, la nueva muestra tendrá una media de 0 y una desviación estándar de 1, lo que facilitará su análisis y comparación con otras muestras.

# %% [markdown]
# ## **Valores o Puntuaciones Z**

# %% [markdown]
# Los valores o puntuaciones Z, también conocidos como Z-Scores, son una medida estadística utilizada para estandarizar y comparar datos en una distribución. Los Z-Scores indican cuántas desviaciones estándar se encuentra un valor particular con respecto a la media de la distribución.
#
# La fórmula para calcular el Z-Score de un valor individual `x` en una distribución con media `media` y desviación estándar `desviacion_estandar` es:
#
# ```
# Z = (x - media) / desviacion_estandar
# ```
#
# Donde:
#
# - `Z` es el Z-Score del valor `x`.
#
# - `x` es el valor individual.
#
# - `media` es la media de la distribución.
#
# - `desviacion_estandar` es la desviación estándar de la distribución.
#
# **Interpretación de los Z-Scores:**
#
# - Si el Z-Score es 0, significa que el valor `x` es igual a la media `media`.
#
# - Si el Z-Score es positivo, el valor `x` está por encima de la media `media`.
#
# - Si el Z-Score es negativo, el valor `x` está por debajo de la media `media`.
#
# - Cuanto mayor sea el valor absoluto del Z-Score, más lejos está el valor `x` de la media `media` en términos de desviaciones estándar.
#
# **Importancia de los Z-Scores:**
#
# Los Z-Scores son importantes porque permiten comparar diferentes conjuntos de datos que pueden tener unidades de medida diferentes o escalas distintas. Al estandarizar los datos, se puede evaluar la posición relativa de un valor en una distribución en comparación con otros valores, independientemente de las unidades de medida o escalas utilizadas.
#
# Además, los Z-Scores son útiles para identificar valores atípicos (outliers). Valores con Z-Scores significativamente altos o bajos en una distribución pueden ser considerados como datos inusuales o anómalos.
#
# **Ejemplo de Cálculo de Z-Scores con Python:**
#
# Vamos a calcular los Z-Scores para una muestra de datos utilizando Python y la biblioteca NumPy.

# %%
import numpy as np

# Datos de la muestra
muestra_datos = np.array([32, 45, 38, 55, 48, 52, 47, 50, 42, 44])

# Calcular la media y desviación estándar de la muestra
media_muestra = np.mean(muestra_datos)
desviacion_estandar_muestra = np.std(muestra_datos)

# Calcular los Z-Scores para cada valor en la muestra
z_scores = (muestra_datos - media_muestra) / desviacion_estandar_muestra

# Mostrar los Z-Scores
print("Z-Scores:", z_scores)
# Out:
# Z-Scores: [-2.06680273 -0.04661961 -1.13441052  1.5073674   0.41957649  1.0411713
#   0.26417779  0.7303739  -0.51281571 -0.20201831]

# %% [markdown]
# **Resultado:**
#
# Los Z-Scores se calcularán para cada valor en la muestra y se mostrarán en la salida. Los Z-Scores indicarán cuántas desviaciones estándar están por encima o por debajo de la media para cada valor en la muestra.
#
# Recuerda que los Z-Scores son una herramienta útil para estandarizar y comparar datos, y son ampliamente utilizados en estadística para diversos análisis y pruebas. También pueden ayudar a identificar valores atípicos y entender la posición relativa de un valor en una distribución.

# %% [markdown]
# ## **Propiedades**

# %% [markdown]
# Las propiedades de los Z-Scores (Puntuaciones Z) son fundamentales para entender su utilidad y cómo se aplican en estadística. A continuación, se presentan las principales propiedades de los Z-Scores:
#
# 1. **Estandarización de Datos:**
#
#  La principal propiedad de los Z-Scores es que permiten estandarizar los datos, es decir, transformarlos para que tengan una media de 0 y una desviación estándar de 1. Esto facilita la comparación y el análisis de datos que provienen de diferentes distribuciones o con unidades de medida distintas.
#
# 2. **Relación con la Media:**
#
#  Si calculamos los Z-Scores para todos los valores en una muestra, la suma de los Z-Scores siempre será igual a cero. Esto se debe a que, al estandarizar los datos, estamos centrando la distribución en cero.
#
# 3. **Relación con la Desviación Estándar:**
#
#  Si multiplicamos todos los Z-Scores por una constante, la desviación estándar de la muestra original también se multiplicará por esa constante. Esto significa que los Z-Scores mantienen una relación lineal con la desviación estándar.
#
# 4. **Identificación de Valores Atípicos:**
#
#  Los Z-Scores también son útiles para identificar valores atípicos (outliers). Valores con Z-Scores significativamente altos o bajos en una distribución pueden considerarse como datos inusuales o anómalos.
#
# 5. **Comparación entre Distribuciones:**
#
#  Los Z-Scores permiten comparar directamente diferentes conjuntos de datos, ya que se encuentran en la misma escala común. Esto es útil para comparar resultados de diferentes experimentos o estudios.
#
# 6. **Transformación de Datos Asimétricos:**
#
#  Si los datos tienen una distribución asimétrica, los Z-Scores pueden ayudar a transformarlos en una distribución más cercana a la normalidad, lo que puede facilitar el análisis y la interpretación de los resultados.
#
# 7. **Utilidad en Pruebas Estadísticas:**
#
#  Los Z-Scores son fundamentales para muchas pruebas estadísticas y análisis, como las pruebas de hipótesis y los intervalos de confianza. Facilitan la estandarización de los datos de muestra y permiten realizar comparaciones significativas.
#
# 8. **Transformación de Variables Aleatorias:**
#
#  Los Z-Scores son útiles en la teoría de probabilidad para transformar variables aleatorias en variables con distribución normal estándar, lo que simplifica los cálculos y análisis.
#
# Es importante recordar que los Z-Scores solo son aplicables cuando los datos siguen una distribución normal o cuando la muestra es lo suficientemente grande como para que se aplique el Teorema del Límite Central. Si los datos no siguen una distribución normal, es posible que los Z-Scores no sean representativos o no tengan el mismo significado interpretativo.
#
# En resumen, los Z-Scores son una herramienta esencial en estadística para estandarizar y comparar datos, identificar valores atípicos y realizar pruebas y análisis significativos. Su aplicación es amplia y se utiliza en diversas áreas, como la investigación científica, el análisis de datos y la toma de decisiones basadas en datos.

# %% [markdown]
# ## **Distribución Normal Estándar y Probabilidad**

# %% [markdown]
# La Distribución Normal Estándar, también conocida como Distribución Normal Z o Distribución Normal Estandarizada, es una distribución de probabilidad especial que tiene una media de 0 y una desviación estándar de 1. Esta distribución es una forma específica de la Distribución Normal que ha sido estandarizada para que sus valores se encuentren en una escala común.
#
# **Características de la Distribución Normal Estándar:**
#
# 1. **Media igual a 0:**
#
#  La media de la distribución normal estándar es 0.
#
# 2. **Desviación Estándar igual a 1:**
#
#  La desviación estándar de la distribución normal estándar es 1.
#
# 3. **Forma de campana:**
#
#  La curva tiene una forma de campana simétrica, igual que la Distribución Normal.
#
# **Función de Densidad de Probabilidad (PDF) de la Distribución Normal Estándar:**
#
# La función de densidad de probabilidad de la Distribución Normal Estándar se puede expresar matemáticamente como:
#
# ```
# f(x) = (1 / √(2π)) * e^(-x^2/2)
# ```
#
# donde:
#
# - `x` es la variable aleatoria.
#
# - `π` es el número pi (aproximadamente 3.14159).
#
# - `e` es la base del logaritmo natural (aproximadamente 2.71828).
#
# **Gráfica de la Distribución Normal Estándar:**
#
# La gráfica de la Distribución Normal Estándar muestra una curva simétrica alrededor del eje vertical en `x = 0`, que representa la media. La curva tiene un pico en `x = 0` y se extiende hacia ambos lados, tendiendo a cero a medida que se aleja de la media.
#
# **Probabilidad en la Distribución Normal Estándar:**
#
# La probabilidad en la Distribución Normal Estándar se representa por el área bajo la curva de densidad de probabilidad en un intervalo específico. En una distribución continua, la probabilidad de obtener un valor exacto es igual a cero debido a la infinitud de valores posibles.
#
# Para calcular la probabilidad de que una variable aleatoria caiga en un rango particular de valores, se integra la función de densidad de probabilidad sobre ese rango. El área bajo la curva en un intervalo representa la probabilidad de que una variable aleatoria se encuentre en ese rango.
#
# **Ejemplo con Python:**
#
# Vamos a utilizar Python y la biblioteca Matplotlib para graficar la función de densidad de probabilidad de la Distribución Normal Estándar y calcular la probabilidad de que una variable aleatoria caiga en un rango específico.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Crear un conjunto de valores en el rango de -3 a 3
x = np.linspace(-3, 3, 1000)

# Calcular la función de densidad de probabilidad para la Distribución Normal Estándar
pdf = (1 / np.sqrt(2 * np.pi)) * np.exp(-x**2 / 2)

# Graficar la Distribución Normal Estándar
plt.plot(x, pdf, label='Distribución Normal Estándar')

# Seleccionar el rango de interés en la Distribución Normal Estándar
rango_interes_x = x[np.logical_and(x >= -1, x <= 1)]
rango_interes_pdf = pdf[np.logical_and(x >= -1, x <= 1)]

# Calcular la probabilidad de que la variable aleatoria esté en el rango de -1 a 1
probabilidad = np.trapz(rango_interes_pdf, rango_interes_x)

# Rellenar el área bajo la curva en el rango de interés
plt.fill_between(rango_interes_x, rango_interes_pdf, alpha=0.5, label=f'Probabilidad: {probabilidad:.3f}')

plt.xlabel('Valores')
plt.ylabel('Densidad de Probabilidad')
plt.title('Distribución Normal Estándar')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Resultado:**
#
# El código generará una gráfica que muestra la curva de la Distribución Normal Estándar. También calculará y sombreará el área bajo la curva en el rango de -1 a 1, que representa la probabilidad de que una variable aleatoria esté en ese rango.
#
# Recuerda que en una distribución normal estándar, la probabilidad de obtener un valor exacto es igual a cero debido a la infinitud de valores posibles. La probabilidad se mide como el área bajo la curva en un rango específico, y esta área representa la probabilidad de que una variable aleatoria se encuentre en ese rango.

# %% [markdown]
# ## **Probabilidades con Python**

# %% [markdown]
# Python cuenta con varias bibliotecas que facilitan el cálculo de probabilidades en diversas distribuciones. A continuación, te mostraré cómo calcular probabilidades usando Python con las bibliotecas NumPy y SciPy para la Distribución Normal Estándar.
#
# **Cálculo de Probabilidades en la Distribución Normal Estándar:**
#
# Para calcular probabilidades en la Distribución Normal Estándar, primero necesitamos importar las bibliotecas NumPy y SciPy. NumPy se utiliza para operaciones numéricas, mientras que SciPy proporciona funciones para trabajar con distribuciones de probabilidad.
#
# **Ejemplo:**
#
# Supongamos que queremos calcular la probabilidad de que una variable aleatoria en la Distribución Normal Estándar esté entre -1 y 1.

# %%
import numpy as np
from scipy.stats import norm

# Definir el rango de interés
rango_inferior = -1
rango_superior = 1

# Calcular la probabilidad usando SciPy
probabilidad = norm.cdf(rango_superior) - norm.cdf(rango_inferior)

# Mostrar la probabilidad
print(f'La probabilidad de que la variable aleatoria esté entre -1 y 1 es: {probabilidad:.4f}')
# Out:
# La probabilidad de que la variable aleatoria esté entre -1 y 1 es: 0.6827

# %% [markdown]
# **Resultado:**
#
# El código imprimirá la probabilidad de que la variable aleatoria esté entre -1 y 1.
#
# **Interpretación:**
#
# En este ejemplo, hemos utilizado la función `norm.cdf` de SciPy para calcular la función de distribución acumulada (CDF) en los límites del rango. La CDF representa la probabilidad acumulada de que la variable aleatoria sea menor o igual a un valor dado. Restamos la CDF del límite superior y la CDF del límite inferior para obtener la probabilidad de que la variable aleatoria esté entre esos dos valores.
#
# Recuerda que, en una Distribución Normal Estándar, la probabilidad de obtener un valor exacto es igual a cero debido a la infinitud de valores posibles. La probabilidad se mide como el área bajo la curva en un rango específico, y esta área representa la probabilidad de que una variable aleatoria se encuentre en ese rango.
#
# Además de la Distribución Normal Estándar, Python y las bibliotecas NumPy y SciPy ofrecen funcionalidades para trabajar con otras distribuciones de probabilidad. Esto te permite calcular probabilidades en diferentes distribuciones y realizar análisis estadísticos más avanzados.

# %% [markdown]
# | **Inicio** | **atrás 5** | **Siguiente 7** |
# |----------- |-------------- |---------------|
# | [🏠](../../README.md) | [⏪](./5_Intervalos_de_Confianza.ipynb)| [⏩](./7_la_Matriz_de_Covarianza.ipynb)|
