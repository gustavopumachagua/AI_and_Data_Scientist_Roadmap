# %% [markdown]
# | **Inicio** | **Siguiente 2** |
# |----------- |---------------|
# | [🏠](../../README.md) | [⏩](./02_Matematica_aplicada_al_aprendizaje_automático_algebra_lineal.ipynb)|

# %% [markdown]
# # **01 Matemática aplicada al aprendizaje automático: álgebra lineal**

# %% [markdown]
# ## **1.1 Introducción al álgebra lineal y a las matemáticas para el aprendizaje automático**

# %% [markdown]
# En este primer módulo veremos cómo el álgebra lineal es relevante para el aprendizaje automático y la ciencia de datos. Luego terminaremos el módulo con una introducción inicial a los vectores. En todo momento, nos centraremos en desarrollar su intuición matemática, no en machacar con álgebra o hacer largos ejemplos de lápiz y papel. Para muchas de estas operaciones, existen funciones invocables en Python que pueden hacer la suma - la cuestión es apreciar lo que hacen y cómo funcionan para que, cuando las cosas vayan mal o haya casos especiales, pueda entender por qué y qué hacer.

# %% [markdown]
# ### **1.1.1 Introducción: Resolver los retos de la ciencia de datos con matemáticas**

# %% [markdown]
# La ciencia de datos es un campo interdisciplinario que utiliza técnicas matemáticas, estadísticas, y de computación para analizar y interpretar grandes volúmenes de datos. Las matemáticas juegan un papel crucial en casi todos los aspectos de la ciencia de datos, desde la recolección y limpieza de datos hasta el modelado y la interpretación de resultados. Aquí te presento una introducción detallada, con ejemplos prácticos y gráficas generadas en Python, que te ayudarán a entender cómo resolver los retos de la ciencia de datos utilizando matemáticas.
#
# **Estadística Descriptiva**
#
# La estadística descriptiva ayuda a describir, mostrar o resumir datos de manera que puedan ser entendidos fácilmente. Esto es especialmente útil al comenzar cualquier análisis de datos para obtener una vista general de la información.
#
# * **Ejemplo:**
#
# Vamos a generar algunos datos y calcular estadísticas descriptivas básicas como la media, mediana y desviación estándar.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Usando un estilo predefinido de matplotlib para el fondo y la cuadrícula
plt.style.use('ggplot')

# Generando datos aleatorios
data = np.random.normal(loc=0, scale=1, size=1000)

# Calculando estadísticas descriptivas
mean = np.mean(data)
median = np.median(data)
std_dev = np.std(data)

# Creando el histograma
plt.hist(data, bins=30, alpha=0.5, color='blue', edgecolor='white')

# Lineas para la media y la mediana
plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Media: {mean:.2f}')
plt.axvline(median, color='green', linestyle='dashdot', linewidth=2, label=f'Mediana: {median:.2f}')

# Añadiendo título y etiquetas con personalización
plt.title("Histograma de Datos con Media y Mediana", fontsize=16, fontweight='bold', color='navy')
plt.xlabel("Valor", fontsize=14, fontstyle='italic')
plt.ylabel("Frecuencia", fontsize=14, fontstyle='italic')

# Modificando la leyenda
plt.legend(loc='upper right', frameon=True, facecolor='lightgrey', framealpha=0.9, edgecolor='black')

# Personalizando los ticks
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)

# Mostrando la cuadrícula
plt.grid(True, linestyle='--', alpha=0.6)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Probabilidad**
#
# La probabilidad permite modelar y estudiar incertidumbres. Es fundamental para los métodos de inferencia estadística y aprendizaje automático.
#
# * **Ejemplo:**
#
# Simulación de lanzamientos de una moneda para entender la probabilidad de obtener cara o cruz.

# %%
import numpy as np

# Función para simular lanzamientos de moneda
def lanzar_moneda(n):
    lanzamientos = np.random.randint(0, 2, size=n)
    caras = np.sum(lanzamientos)
    return caras, n - caras

n_lanzamientos = 1000
caras, cruces = lanzar_moneda(n_lanzamientos)

print(f"En {n_lanzamientos} lanzamientos, salió cara {caras} veces y cruz {cruces} veces.")
# Out:
# En 1000 lanzamientos, salió cara 502 veces y cruz 498 veces.

# %% [markdown]
# **Regresión Lineal**
#
# La regresión lineal es una técnica estadística usada para modelar la relación entre una variable dependiente y una o más variables independientes.
#
# * **Ejemplo:**
#
# Vamos a simular algunos datos y ajustar un modelo de regresión lineal.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Datos simulados
x = np.random.rand(100, 1) * 100  # Características (independientes)
y = 3 * x + np.random.randn(100, 1) * 30 + 50  # Variable dependiente

# Ajuste del modelo de regresión
model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)

# Gráfica de los datos y la línea de ajuste
plt.figure(figsize=(10, 6))  # Ajustando el tamaño de la figura
plt.scatter(x, y, alpha=0.6, color='blue', edgecolor='black', label='Datos')  # Puntos de datos
plt.plot(x, y_pred, color='darkred', linewidth=2, label='Línea de Regresión')  # Línea de regresión
plt.title("Análisis de Regresión Lineal", fontsize=14, fontweight='bold', color='darkblue')  # Título
plt.xlabel("Variable Independiente", fontsize=12)  # Etiqueta del eje X
plt.ylabel("Variable Dependiente", fontsize=12)  # Etiqueta del eje Y
plt.legend(frameon=True, loc='best', fontsize=10)  # Leyenda
plt.grid(True, linestyle='--', alpha=0.5)  # Grilla personalizada
plt.show()  # Mostrar gráfico

# %% [markdown]
# La relación entre una variable dependiente y una o más variables independientes es un concepto central en muchos tipos de análisis estadístico y modelado predictivo, particularmente en la regresión. Aquí te explico detalladamente:
#
# **Variable Dependiente**
#
# La **variable dependiente** es la que se quiere predecir o explicar en un modelo estadístico. Esta variable se considera "dependiente" porque su valor se presume que depende de los valores de otras variables. Por ejemplo, en un estudio sobre el rendimiento académico, la variable dependiente podría ser la calificación final de un estudiante, que se intenta predecir a partir de otros factores.
#
# **Variables Independientes**
#
# Las **variables independientes** son aquellas que se utilizan para predecir el valor de la variable dependiente. En teoría, se consideran independientes porque se presume que son la causa de los cambios en la variable dependiente. En el ejemplo del rendimiento académico, las variables independientes podrían incluir horas de estudio, asistencia a clase, y otros factores socioeconómicos que podrían influir en las calificaciones de los estudiantes.
#
# **Relación entre Variables**
#
# El análisis de la relación entre la variable dependiente y las variables independientes implica examinar cómo cambia la primera en respuesta a variaciones en las segundas. Este análisis se puede hacer a través de varios métodos estadísticos, siendo la regresión lineal uno de los más comunes.
#
# **Ejemplo de Regresión Lineal:**
#
# En un modelo de regresión lineal simple, donde solo hay una variable independiente, la relación se modela como una línea recta:
#
# $Y = \beta_0 + \beta_1X + \epsilon$
#
# donde:
#
# - $(Y)$ es la variable dependiente.
#
# - $(X)$ es la variable independiente.
#
# - $(\beta_0)$ es el intercepto, el valor esperado de $(Y)$ cuando $(X)$ es 0.
#
# - $(\beta_1)$ es la pendiente, que indica el cambio en $(Y)$ por una unidad de cambio en $(X)$.
#
# - $(\epsilon)$ es el término de error, que captura la variación en $(Y)$ no explicada por $(X)$.
#
# **Importancia en la Ciencia de Datos**
#
# Entender y modelar correctamente estas relaciones es crucial en la ciencia de datos, ya que permite:
#
# - **Predecir** valores futuros de la variable dependiente basándose en los valores de las variables independientes.
#
# - **Interpretar** la influencia de cada variable independiente sobre la dependiente, lo cual es vital para comprender los mecanismos subyacentes en muchos campos, desde la economía hasta la biología.
#
# Mediante el estudio de estas relaciones, los científicos y analistas pueden formular recomendaciones, tomar decisiones informadas, y desarrollar estrategias basadas en un entendimiento sólido y cuantitativo de los datos.

# %% [markdown]
# **Conclusión**
#
# Las matemáticas son fundamentales en la ciencia de datos para diseñar modelos que interpretan correctamente los datos y para asegurar que las conclusiones basadas en esos datos sean válidas y útiles. Los ejemplos proporcionados ilustran cómo se pueden aplicar técnicas estadísticas básicas y modelos matemáticos para comenzar a resolver problemas en este campo.

# %% [markdown]
# ### **1.1.2 Motivaciones para el álgebra lineal**

# %% [markdown]
# El álgebra lineal es una rama fundamental de las matemáticas aplicadas, que se enfoca en el estudio de vectores, espacios vectoriales (también conocidos como espacios lineales), transformaciones lineales, y sistemas de ecuaciones lineales. Es esencial en casi todos los campos de la ciencia y la ingeniería, proporcionando herramientas para describir y resolver una amplia gama de problemas prácticos. Aquí exploraremos algunas motivaciones para el estudio del álgebra lineal, con ejemplos prácticos, fórmulas matemáticas y visualizaciones en Python.
#
# **Sistemas de Ecuaciones Lineales**
#
# Uno de los usos más inmediatos del álgebra lineal es resolver sistemas de ecuaciones lineales. Estos sistemas aparecen en contextos como la economía (para modelar equilibrios de mercado), ingeniería (balance de fuerzas), y en la computación (algoritmos y estructuras de datos).
#
# **Ejemplo Matemático:**
#
# Consideremos el sistema de ecuaciones lineales:
#
# \begin{align*}
# x + 2y &= 5 \\
# 3x + 4y &= 11
# \end{align*}
#
# Podemos resolver este sistema usando matrices.

# %%
import numpy as np

# Definir la matriz de coeficientes y el vector de términos independientes
A = np.array([[1, 2], [3, 4]])
b = np.array([5, 11])

# Resolver el sistema de ecuaciones
solucion = np.linalg.solve(A, b)

print(f"La solución del sistema es x = {solucion[0]}, y = {solucion[1]}")
# Out:
# La solución del sistema es x = 1.0, y = 2.0

# %% [markdown]
# **Transformaciones Lineales y Cambio de Base**
#
# Las transformaciones lineales son funciones entre espacios vectoriales que preservan las operaciones de suma de vectores y multiplicación por escalares. Estas son cruciales para entender cambios de coordenadas y perspectivas en física y gráficos por computadora.
#
# **Ejemplo de Rotación en el Plano:**
#
# Una rotación en el plano puede ser descrita por una matriz de transformación. Si queremos rotar puntos en el plano por un ángulo $(\theta)$, usamos la matriz:
#
# $
# R(\theta) = \begin{bmatrix}
# \cos(\theta) & -\sin(\theta) \\
# \sin(\theta) & \cos(\theta)
# \end{bmatrix}
# $

# %%
import numpy as np
import matplotlib.pyplot as plt

# Función para rotar un punto
def rotar_punto(punto, theta):
    R = np.array([
        [np.cos(theta), -np.sin(theta)],
        [np.sin(theta), np.cos(theta)]
    ])
    return np.dot(R, punto)

# Punto original y punto rotado
punto_original = np.array([1, 0])
punto_rotado = rotar_punto(punto_original, np.pi / 4)  # Rotar 45 grados

# Graficar
plt.figure(figsize=(6, 6))  # Ajustando el tamaño de la figura
plt.plot([0, punto_original[0]], [0, punto_original[1]], 'ro-', label='Original', linewidth=2, markersize=8)
plt.plot([0, punto_rotado[0]], [0, punto_rotado[1]], 'bo-', label='Rotado', linewidth=2, markersize=8)
plt.axis('equal')
plt.legend(frameon=True, loc='upper right', fontsize=10)  # Leyenda
plt.title('Rotación de un Punto en el Plano', fontsize=14, fontweight='bold', color='navy')  # Título
plt.xlabel('X', fontsize=12)  # Etiqueta del eje X
plt.ylabel('Y', fontsize=12)  # Etiqueta del eje Y
plt.grid(True, linestyle='--', alpha=0.7)  # Grilla personalizada

# Añadir anotaciones para los puntos
plt.annotate('Original (1,0)', xy=punto_original, xytext=(10, -10), textcoords='offset points', arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.5'))
plt.annotate('Rotado', xy=punto_rotado, xytext=(-90, 0), textcoords='offset points', arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.5'))

plt.show()  # Mostrar gráfico

# %% [markdown]
# **Análisis de Datos y Machine Learning**
#
# El álgebra lineal es esencial en el análisis de datos y machine learning para técnicas como la reducción de dimensionalidad (PCA), clustering, y redes neuronales. Estos métodos dependen de operaciones con matrices y vectores para procesar y extraer patrones de grandes conjuntos de datos.
#
# **Ejemplo de PCA (Análisis de Componentes Principales):**
#
# El PCA busca reducir la dimensionalidad de los datos identificando las principales direcciones en las que varían los datos.

# %%
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Datos simulados en 3D
np.random.seed(0)
data = np.random.randn(100, 3)

# Aplicar PCA para reducir a 2 dimensiones
pca = PCA(n_components=2)
data_transformada = pca.fit_transform(data)

# Graficar
plt.figure(figsize=(8, 6))  # Ajustando el tamaño de la figura
plt.scatter(data_transformada[:, 0], data_transformada[:, 1], c='magenta', alpha=0.5, edgecolor='black', s=50)  # Cambio de color, tamaño y bordes de los puntos
plt.title('Visualización PCA - Componentes Principales', fontsize=14, fontweight='bold')  # Título personalizado
plt.xlabel('Componente Principal 1', fontsize=12)  # Etiqueta del eje X personalizada
plt.ylabel('Componente Principal 2', fontsize=12)  # Etiqueta del eje Y personalizada
plt.grid(True, linestyle='--', alpha=0.7)  # Grilla personalizada
plt.show()  # Mostrar gráfico

# %% [markdown]
# ### **1.1.3 Dominar los vectores**

# %% [markdown]
# Los vectores son una parte esencial del álgebra lineal y tienen numerosas aplicaciones en física, ingeniería, ciencias de la computación y análisis de datos. Un vector se puede considerar como una representación de una magnitud que tiene dirección y tamaño. En este contexto, vamos a explorar cómo trabajar con vectores en Python, incluyendo cómo realizar operaciones básicas, visualizaciones y aplicaciones prácticas.
#
# **Conceptos Básicos de Vectores**
#
# Un vector en matemáticas es una entidad que tiene tanto magnitud como dirección. Puede representarse en varias dimensiones, siendo los vectores en 2D y 3D los más comunes en visualización.
#
# **Representación de un Vector**
#
# En 2 dimensiones, un vector $(\mathbf{v})$ puede ser representado como:
#
# $\mathbf{v} = \begin{pmatrix} x \\ y \end{pmatrix}$
#
# donde $(x)$ y $(y)$ son las componentes horizontal y vertical del vector, respectivamente.

# %%
import numpy as np

v = np.array([2, 3])
print("Vector v:", v)
# Out:
# Vector v: [2 3]

# %% [markdown]
# **Operaciones Básicas con Vectores**
#
# Las operaciones fundamentales con vectores incluyen la suma, la resta, el producto escalar y el producto vectorial (este último solo en 3D).
#
# **Suma de Vectores**
#
# La suma de dos vectores se realiza sumando sus correspondientes componentes:
#
# $\mathbf{v} + \mathbf{w} = \begin{pmatrix} v_x + w_x \\ v_y + w_y \end{pmatrix}$
#
# **Ejemplo:**

# %%
w = np.array([1, 2])
suma = v + w
print("Suma de v y w:", suma)
# Out:
# Suma de v y w: [3 5]

# %% [markdown]
# **Producto Escalar**
#
# El producto escalar (o producto punto) de dos vectores es una operación que resulta en un escalar. Se calcula como:
#
# $\mathbf{v} \cdot \mathbf{w} = v_x \times w_x + v_y \times w_y$
#
# **Ejemplo:**

# %%
producto_punto = np.dot(v, w)
print("Producto punto de v y w:", producto_punto)
# Out:
# Producto punto de v y w: 8

# %% [markdown]
# **Visualización de Vectores**
#
# La visualización de vectores es crucial para entender su dirección y magnitud de manera intuitiva. Podemos usar Matplotlib para graficar vectores en Python.
#
# **Ejemplo de Gráfico de Vectores:**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir los vectores
v = np.array([3, 4])
w = np.array([1, 2])

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(8, 6))  # Ajustando el tamaño de la figura

# Graficar el vector v
ax.quiver(0, 0, *v, scale=1, scale_units='xy', angles='xy', color='darkred', width=0.015, label='Vector v (3,4)')
ax.quiver(0, 0, *w, scale=1, scale_units='xy', angles='xy', color='navy', width=0.015, label='Vector w (1,2)')

# Establecer límites para los ejes
ax.set_xlim(0, 5)
ax.set_ylim(0, 5)

# Añadir cuadrícula
ax.grid(True, linestyle='--', alpha=0.5)  # Grilla personalizada

# Hacer que los ejes tengan la misma proporción para que los vectores se muestren correctamente
ax.set_aspect('equal')

# Añadir título y leyenda
ax.set_title('Visualización de Vectores', fontsize=14, fontweight='bold')  # Título personalizado
ax.legend(loc='upper right', fontsize=10)  # Leyenda personalizada

# Anotaciones para cada vector
ax.annotate('Vector v (3,4)', xy=(1.5, 2), xytext=(3, 4), arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.5', color='darkred'))
ax.annotate('Vector w (1,2)', xy=(0.5, 1), xytext=(1, 2), arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.5', color='navy'))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Aplicación Práctica: Movimiento en Física**
#
# Los vectores son muy utilizados para describir movimientos en física, donde cada vector puede representar la posición, velocidad o aceleración de un objeto en el espacio.
#
# **Ejemplo:**
#
# Supongamos que un objeto se mueve con una velocidad inicial representada por el vector $\mathbf{v} = \begin{pmatrix} 2 \\ 3 \end{pmatrix}$ metros/segundo. Queremos calcular su posición después de 5 segundos si sigue moviéndose en la misma dirección y velocidad.

# %%
tiempo = 5  # segundos
posicion_final = v * tiempo  # Operación elemento a elemento
print("Posición final después de 5 segundos:", posicion_final)
# Out:
# Posición final después de 5 segundos: [15 20]

# %% [markdown]
# **Conclusión**
#
# Dominar los vectores implica entender cómo se representan, cómo se manipulan matemáticamente y cómo se pueden visualizar y aplicar en contextos reales. Las habilidades en álgebra vectorial son fundamentales en diversas áreas de la ciencia y tecnología, y la capacidad de implementar y visualizar estas operaciones en Python es una herramienta invaluable en la ciencia de datos y más allá.

# %% [markdown]
# ### **1.1.4 Operaciones con vectores**

# %% [markdown]
# Operar con vectores es fundamental en muchas disciplinas científicas y técnicas, incluyendo física, ingeniería y ciencias de la computación. Vamos a detallar algunas operaciones básicas con vectores, cómo se representan matemáticamente, y cómo podemos implementar y visualizar estas operaciones en Python.
#
# **Tipos de Operaciones Vectoriales**
#
# 1. **Suma de Vectores**
#
# 2. **Resta de Vectores**
#
# 3. **Multiplicación por Escalar**
#
# 4. **Producto Punto (o Escalar)**
#
# 5. **Producto Cruz (solo para vectores en 3D)**
#
# **Suma de Vectores**
#
# La **suma de dos vectores** se realiza añadiendo las componentes correspondientes de cada vector.
#
# **Fórmula Matemática**
#
# Si tenemos dos vectores $\mathbf{u} = (u_1, u_2)$ y $\mathbf{v} = (v_1, v_2)$, la suma es:
#
# $\mathbf{u} + \mathbf{v} = (u_1 + v_1, u_2 + v_2)$
#
# **Ejemplo:**

# %%
import numpy as np

# Definir dos vectores
u = np.array([2, 5])
v = np.array([3, 1])

# Sumar vectores
suma = u + v
print("Suma de vectores:", suma)
# Out:
# Suma de vectores: [5 6]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Función para graficar vectores
def plot_vector(vec, origin, color, label):
    plt.quiver(*origin, *vec, scale=1, scale_units='xy', angles='xy', color=color, width=0.02, label=label)  # Ajuste en el ancho

# Definir vectores
u = np.array([2, 5])
v = np.array([3, 1])
suma = u + v

# Crear la figura y los ejes
fig, ax = plt.subplots(figsize=(8, 6))  # Ajustar tamaño de la figura

# Graficar vectores
plot_vector(u, [0, 0], 'red', 'Vector u (2,5)')
plot_vector(v, [0, 0], 'blue', 'Vector v (3,1)')
plot_vector(suma, [0, 0], 'green', 'Suma u+v')

# Establecer límites para los ejes
ax.set_xlim(0, 6)
ax.set_ylim(0, 6)

# Añadir cuadrícula
ax.grid(True, linestyle='--', alpha=0.7)  # Grilla personalizada

# Hacer que los ejes tengan la misma proporción para que los vectores se muestren correctamente
ax.set_aspect('equal')

# Añadir título y leyenda
ax.set_title('Suma de Vectores', fontsize=14, fontweight='bold')  # Título personalizado
ax.legend(loc='upper right', fontsize=10)  # Leyenda personalizada

# Añadir anotaciones para cada vector
ax.annotate('u (2,5)', xy=(1, 2.5), xytext=(2, 5), textcoords="offset points", arrowprops=dict(arrowstyle='->', color='red'))
ax.annotate('v (3,1)', xy=(1.5, 0.5), xytext=(3, 1), textcoords="offset points", arrowprops=dict(arrowstyle='->', color='blue'))
ax.annotate('u+v (5,6)', xy=(2.5, 3), xytext=(5, 6), textcoords="offset points", arrowprops=dict(arrowstyle='->', color='green'))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Resta de Vectores**
#
# La **resta de vectores** se realiza restando las componentes del segundo vector de las del primero.
#
# **Fórmula Matemática**
#
# $\mathbf{u} - \mathbf{v} = (u_1 - v_1, u_2 - v_2)$
#
# **Ejemplo:**

# %%
# Restar vectores
resta = u - v
print("Resta de vectores:", resta)
# Out:
# Resta de vectores: [-1  4]

# %% [markdown]
# **Multiplicación por Escalar**
#
# La **multiplicación de un vector por un escalar** amplía o reduce la magnitud del vector sin cambiar su dirección.
#
# **Fórmula Matemática**
#
# $k \mathbf{v} = (k v_1, k v_2)$
#
# **Ejemplo:**

# %%
# Multiplicar vector por un escalar
k = 3
escalar_multiplicacion = k * v
print("Multiplicación por escalar:", escalar_multiplicacion)
# Out:
# Multiplicación por escalar: [9 3]

# %% [markdown]
# **Producto Punto**
#
# El **producto punto** entre dos vectores es una operación fundamental que resulta en un escalar, el cual es el producto de las magnitudes de los vectores y el coseno del ángulo entre ellos.
#
# **Fórmula Matemática**
#
# $\mathbf{u} \cdot \mathbf{v} = u_1 v_1 + u_2 v_2$
#
# **Ejemplo:**

# %%
# Producto punto
producto_punto = np.dot(u, v)
print("Producto punto:", producto_punto)
# Out:
# Producto punto: 11

# %% [markdown]
# **Producto Cruz**
#
# El **producto cruz** es específico para vectores en tres dimensiones y resulta en un vector perpendicular a ambos vectores originales.
#
# **Fórmula Matemática**
#
# $\mathbf{u} \times \mathbf{v} = (u_2 v_3 - u_3 v_2, u_3 v_1 - u_1 v_3, u_1 v_2 - u_2 v_1)$
#
# **Ejemplo:**

# %%
# Definir vectores en 3D
u = np.array([2, 5, 0])
v = np.array([3, 1, 0])

# Producto cruz
producto_cruz = np.cross(u, v)
print("Producto cruz:", producto_cruz)
# Out:
# Producto cruz: [  0   0 -13]

# %% [markdown]
# Cada una de estas operaciones tiene aplicaciones específicas en diversos campos, desde la física, donde vectores pueden representar fuerzas o velocidades, hasta la ciencia de datos y el aprendizaje automático, donde los vectores se utilizan para modelar características y realizar cálculos en algoritmos. Estos fundamentos son esenciales para una profunda comprensión y habilidad práctica en ciencias aplicadas y tecnología.

# %% [markdown]
# ### **1.1.5 Exploración del espacio de parámetros**

# %% [markdown]
# La exploración del espacio de parámetros es un concepto esencial en muchas áreas de la ciencia y la ingeniería, especialmente en estadísticas, machine learning, y física. Se refiere al proceso de analizar cómo las variaciones en los parámetros de un modelo afectan sus predicciones o comportamientos. Esta exploración es crucial para optimizar modelos, entender su sensibilidad y mejorar su interpretación.
#
# **Conceptos Básicos**
#
# **Espacio de parámetros**: Conjunto de todos los posibles valores que pueden tomar los parámetros de un modelo.
#
# **Parámetro**: Variable que se ajusta durante el proceso de calibración de un modelo para mejorar su ajuste a un conjunto de datos.
#
# **Aplicaciones**
#
# 1. **Optimización de Modelos**: Buscar los parámetros que minimizan o maximizan una función objetivo.
#
# 2. **Análisis de Sensibilidad**: Estudiar cómo la variación en los parámetros afecta los resultados del modelo.
#
# 3. **Validación de Modelos**: Asegurar que el modelo funcione bien bajo una amplia gama de condiciones de parámetros.
#
# **Ejemplo en Machine Learning: Optimización de un Modelo de Regresión**
#
# Supongamos que tenemos un modelo de regresión simple y queremos entender cómo varían los errores del modelo con diferentes valores de los parámetros. Vamos a explorar esto con un ejemplo concreto en Python.
#
# **Definición del Problema**
#
# Consideramos un modelo de regresión lineal:
#
# $y = \beta_0 + \beta_1 x + \epsilon$
#
# donde $(\beta_0)$ es el intercepto, $(\beta_1)$ es la pendiente, y $(\epsilon)$ es el término de error.
#
# **Simulación de Datos**
#
# Generamos datos sintéticos donde $(x)$ es una variable independiente y $(y)$ es la variable dependiente afectada por $(x)$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar datos sintéticos
np.random.seed(0)
x = 2 * np.random.rand(100, 1)
y = 4 + 3 * x + np.random.randn(100, 1)

# Visualizar los datos
plt.figure(figsize=(8, 6))  # Ajustando el tamaño de la figura
plt.scatter(x, y, alpha=0.75, color='magenta', edgecolor='black', s=50)  # Cambio de color, tamaño y bordes de los puntos
plt.title('Distribución de Datos Generados', fontsize=14, fontweight='bold', color='navy')  # Título personalizado
plt.xlabel('x - Variable Independiente', fontsize=12)  # Etiqueta del eje X personalizada
plt.ylabel('y - Variable Dependiente', fontsize=12)  # Etiqueta del eje Y personalizada
plt.grid(True, linestyle='--', alpha=0.5)  # Grilla personalizada
plt.show()  # Mostrar gráfico

# %% [markdown]
# **Exploración del Espacio de Parámetros**
#
# Vamos a variar el parámetro $(\beta_1)$ (pendiente) mientras mantenemos $(\beta_0)$ (intercepto) fijo, para ver cómo afecta al error del modelo.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# Generar datos sintéticos
np.random.seed(0)
x = 2 * np.random.rand(100, 1)
y = 4 + 3 * x + np.random.randn(100, 1)

# Rango de valores para beta_1
betas = np.linspace(2.5, 3.5, 200)
errors = []

for beta in betas:
    y_pred = 4 + beta * x  # Usando beta_0 = 4 fijo
    error = mean_squared_error(y, y_pred)
    errors.append(error)

# Graficar beta_1 vs. error
plt.figure(figsize=(8, 6))  # Ajustar tamaño de la figura
plt.plot(betas, errors, color='darkblue', linewidth=2)  # Cambio de color y grosor de la línea
plt.title("Error Cuadrático Medio vs. Pendiente del Modelo", fontsize=14, fontweight='bold')  # Título personalizado
plt.xlabel("Pendiente (\u03B2_1)", fontsize=12)  # Etiqueta del eje X personalizada
plt.ylabel("Error Cuadrático Medio", fontsize=12)  # Etiqueta del eje Y personalizada
plt.grid(True, linestyle='--', alpha=0.5)  # Grilla personalizada
plt.show()  # Mostrar gráfico

# %% [markdown]
# Este gráfico nos muestra cómo varía el error cuadrático medio (MSE) a medida que cambiamos la pendiente del modelo. Podemos observar que hay un valor mínimo de error en algún punto del rango de $(\beta_1)$ explorado, indicando la pendiente óptima para nuestro conjunto de datos sintéticos.
#
# **Conclusión**
#
# Explorar el espacio de parámetros es una técnica poderosa para entender y mejorar modelos en ciencias y ingeniería. Nos permite identificar los mejores parámetros, evaluar la robustez del modelo, y predecir cómo cambios en los parámetros pueden influir en el desempeño del modelo en diferentes condiciones. Esta técnica es fundamental en optimización, análisis de sensibilidad y en el proceso de validación de modelos predictivos.

# %% [markdown]
# ### **1.1.6 Resolver algunas ecuaciones simultáneas**

# %% [markdown]
# Resolver ecuaciones simultáneas, también conocidas como sistemas de ecuaciones lineales, es un problema clásico en álgebra lineal que tiene aplicaciones en numerosos campos como la economía, ingeniería y ciencia de datos. Las ecuaciones simultáneas pueden resolverse mediante varios métodos, incluyendo eliminación gaussiana, regla de Cramer, y métodos matriciales como la inversión de matrices o el uso de la descomposición LU. Aquí exploraremos cómo resolver un sistema de ecuaciones usando matrices en Python, acompañado de explicaciones teóricas y visualizaciones.
#
# **Sistema de Ecuaciones Lineales**
#
# Supongamos que tenemos el siguiente sistema de ecuaciones lineales:
#
#
# \begin{align*}
# x + 2y + 3z &= 9, \\
# 2x + 3y + 7z &= 8, \\
# 4x + y + 2z &= 3.
# \end{align*}
#
#
# Queremos encontrar los valores de $(x)$, $(y)$, y $(z)$ que satisfacen todas estas ecuaciones simultáneamente.
#
# **Representación Matricial**
#
# Este sistema puede representarse en forma matricial como $(A\mathbf{x} = \mathbf{b})$, donde $(A)$ es la matriz de coeficientes, $(\mathbf{x})$ es el vector de incógnitas, y $(\mathbf{b})$ es el vector de términos constantes:
#
# $
# A = \begin{pmatrix}
# 1 & 2 & 3 \\
# 2 & 3 & 7 \\
# 4 & 1 & 2
# \end{pmatrix}, \quad
# \mathbf{x} = \begin{pmatrix}
# x \\
# y \\
# z
# \end{pmatrix}, \quad
# \mathbf{b} = \begin{pmatrix}
# 9 \\
# 8 \\
# 3
# \end{pmatrix}
# $
#
# **Método de Solución en Python**
#
# Vamos a utilizar NumPy, una biblioteca de Python para cálculos numéricos, para resolver este sistema de ecuaciones. Usaremos la función `numpy.linalg.solve()`, que es eficiente y maneja internamente los posibles problemas de precisión numérica asociados con la inversión de matrices.
#
# **Código para Resolver el Sistema**

# %%
import numpy as np

# Definir la matriz A y el vector b
A = np.array([[1, 2, 3],
              [2, 3, 7],
              [4, 1, 2]])

b = np.array([9, 8, 3])

# Resolver el sistema de ecuaciones
x = np.linalg.solve(A, b)

print("Solución del sistema:")
print("x =", x[0])
print("y =", x[1])
print("z =", x[2])
# Out:
# Solución del sistema:
# x = -0.11764705882352944
# y = 7.823529411764705
# z = -2.1764705882352935

# %% [markdown]
# **Verificación de la Solución**
#
# Es importante verificar que la solución obtenida realmente satisface el sistema de ecuaciones original. Podemos hacerlo multiplicando la matriz de coeficientes por el vector solución y comparándolo con el vector de términos constantes.
#
# **Código para Verificar la Solución**

# %%
# Verificar la solución
b_check = np.dot(A, x)
print("Comprobación del resultado:")
print("b calculado =", b_check)
# Out:
# Comprobación del resultado:
# b calculado = [9. 8. 3.]

# %% [markdown]
# **Visualización**
#
# Aunque visualizar un sistema de tres variables en un espacio 3D puede ser complejo, se puede intentar visualizar sistemas de dos variables para entender mejor cómo se intersectan las líneas o planos. Aquí, nos enfocaremos en explicar y resolver el sistema.
#
# **Conclusión**
#
# Resolver sistemas de ecuaciones lineales es fundamental para entender cómo diferentes variables se relacionan entre sí en un modelo. El uso de Python y NumPy facilita la implementación de métodos numéricos complejos con pocas líneas de código, lo que permite a los investigadores y profesionales concentrarse más en el problema y menos en los detalles computacionales. Esta capacidad es esencial para la modelización en ciencia y tecnología modernas.

# %% [markdown]
# ### **1.1.7 Realizar algunas operaciones vectoriales**

# %% [markdown]
# Operar con vectores es una habilidad esencial en matemáticas, física, ingeniería y ciencia de datos. Los vectores se utilizan para representar magnitudes que tienen dirección y sentido, como fuerzas, velocidades, y posiciones. A continuación, exploraremos algunas operaciones vectoriales básicas, con ejemplos prácticos y visualizaciones usando Python.
#
# **Tipos de Operaciones Vectoriales**
#
# 1. **Suma de Vectores**
#
# 2. **Resta de Vectores**
#
# 3. **Multiplicación por un Escalar**
#
# 4. **Producto Escalar (o Producto Punto)**
#
# 5. **Producto Cruz (para vectores en 3D)**
#
# Cada una de estas operaciones ayuda a manipular vectores para diferentes propósitos analíticos y prácticos.
#
# **Suma de Vectores**
#
# La **suma de vectores** implica sumar correspondientes componentes de dos o más vectores.
#
# **Fórmula Matemática**
#
# Si tenemos dos vectores en 2D, $\mathbf{u} = (u_1, u_2)$ y $\mathbf{v} = (v_1, v_2)$, la suma es:
#
# $\mathbf{u} + \mathbf{v} = (u_1 + v_1, u_2 + v_2)$
#
# **Ejemplo:**

# %%
import numpy as np

u = np.array([2, 3])
v = np.array([5, -2])

suma = u + v
print("Suma de vectores:", suma)
# Out:
# Suma de vectores: [7 1]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Función para graficar vectores
def plot_vector(vec, origin, color, name):
    plt.quiver(*origin, *vec, scale=1, scale_units='xy', angles='xy', color=color, label=name, width=0.02)

# Definir vectores
u = np.array([2, 3])
v = np.array([5, -2])
suma = u + v

# Graficar vectores
plot_vector(u, [0, 0], 'red', 'u (2,3)')
plot_vector(v, u, 'blue', 'v (5,-2)')  # origen en la punta de u
plot_vector(suma, [0, 0], 'green', 'u+v')

# Establecer límites para los ejes
plt.xlim(-1, 8)
plt.ylim(-3, 6)

# Mejorar la visualización del gráfico
plt.grid(True, linestyle='--', alpha=0.7)  # Grilla personalizada
plt.axhline(0, color='black', linewidth=1)  # Línea horizontal más visible
plt.axvline(0, color='black', linewidth=1)  # Línea vertical más visible

# Añadir título y leyenda
plt.title('Suma de Vectores', fontsize=14, fontweight='bold')  # Título personalizado
plt.legend(loc='upper right', fontsize=10)  # Leyenda personalizada

# Añadir anotaciones para cada vector
plt.annotate('u (2,3)', xy=(1, 1.5), xytext=(3, 4), textcoords="offset points", arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.5', color='red'))
plt.annotate('v (5,-2)', xy=(u[0] + v[0]/2, u[1] + v[1]/2), xytext=(u[0] + 2.5, u[1] - 1), textcoords="offset points", arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.5', color='blue'))
plt.annotate('u+v (7,1)', xy=(suma[0]/2, suma[1]/2), xytext=(suma[0] - 1, suma[1] + 1), textcoords="offset points", arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.5', color='green'))

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Producto Escalar**
#
# El **producto escalar** (o producto punto) es una operación fundamental que resulta en un escalar, calculado como el producto de las componentes correspondientes de los vectores y sumando los resultados.
#
# **Fórmula Matemática**
#
# $\mathbf{u} \cdot \mathbf{v} = u_1 \times v_1 + u_2 \times v_2$
#
# **Ejemplo:**

# %%
producto_punto = np.dot(u, v)
print("Producto escalar de u y v:", producto_punto)
# Out:
# Producto escalar de u y v: 4

# %% [markdown]
# **Producto Cruz**
#
# El **producto cruz** es específico para vectores en tres dimensiones y resulta en un vector que es perpendicular a ambos vectores de entrada.
#
# **Fórmula Matemática**
#
# $\mathbf{u} \times \mathbf{v} = (u_2 v_3 - u_3 v_2, u_3 v_1 - u_1 v_3, u_1 v_2 - u_2 v_1)$
#
# **Ejemplo:**

# %%
u = np.array([1, 0, 0])
v = np.array([0, 1, 0])

producto_cruz = np.cross(u, v)
print("Producto cruz de u y v:", producto_cruz)
# Out:
# Producto cruz de u y v: [0 0 1]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8, 6))  # Ajustando el tamaño de la figura
ax = fig.add_subplot(111, projection='3d')

# Función para graficar vectores en 3D
def plot_vector3d(ax, vec, origin, color, label):
    ax.quiver(*origin, *vec, color=color, label=label, length=1, arrow_length_ratio=0.1, linewidth=2)

# Definir vectores
u = np.array([1, 0, 0])
v = np.array([0, 1, 0])
producto_cruz = np.cross(u, v)

# Graficar vectores
plot_vector3d(ax, u, [0, 0, 0], 'red', 'u (1,0,0)')
plot_vector3d(ax, v, [0, 0, 0], 'blue', 'v (0,1,0)')
plot_vector3d(ax, producto_cruz, [0, 0, 0], 'green', 'u x v')

# Ajustar los límites del eje para visualización completa
ax.set_xlim([0, 1])
ax.set_ylim([0, 1])
ax.set_zlim([0, 1])

# Etiquetas de los ejes
ax.set_xlabel('X', fontsize=12)
ax.set_ylabel('Y', fontsize=12)
ax.set_zlabel('Z', fontsize=12)

# Añadir título y leyenda
ax.set_title('Visualización 3D de Vectores', fontsize=14, fontweight='bold')
plt.legend(loc='upper right', fontsize=10)  # Leyenda personalizada

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Conclusión**
#
# Estas operaciones vectoriales son herramientas poderosas para el análisis y resolución de problemas en diversas aplicaciones científicas y técnicas. Entender y aplicar correctamente estas operaciones permite interpretar y manipular datos y relaciones espaciales de manera efectiva.

# %% [markdown]
# | **Inicio** | **Siguiente 2** |
# |----------- |---------------|
# | [🏠](../../README.md) | [⏩](./02_Matematica_aplicada_al_aprendizaje_automático_algebra_lineal.ipynb)|
