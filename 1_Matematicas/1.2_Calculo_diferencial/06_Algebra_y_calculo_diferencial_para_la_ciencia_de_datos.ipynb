# %% [markdown]
# | **Inicio** | **atrás 5** |
# |----------- |-------------- |
# | [🏠](../../README.md) | [⏪](./05_Algebra_y_calculo_diferencial_para_la_ciencia_de_datos.ipynb)|

# %% [markdown]
# # **6. Álgebra y cálculo diferencial para la ciencia de datos**

# %% [markdown]
# ## **6.1 Encontrar máximo y mínimos**

# %% [markdown]
# Utilice las derivadas para hallar los valores máximo y mínimo de las funciones.

# %% [markdown]
# ### **6.1.1 Máximos y mínimos de funciones**

# %% [markdown]
# Los máximos y mínimos de funciones son puntos críticos donde una función alcanza su mayor o menor valor, respectivamente, dentro de un intervalo dado. Estos puntos son esenciales para la optimización y se utilizan en diversas aplicaciones prácticas, desde la física hasta la economía.
#
# **Tipos de Máximos y Mínimos**
#
# **Máximos y Mínimos Locales**
#
# - **Máximo Local**: Un punto $(x = c)$ es un máximo local de $f(x)$ si $f(c)$ es mayor que los valores de $f(x)$ en todos los puntos cercanos a $(c)$.
#
# - **Mínimo Local**: Un punto $(x = c)$ es un mínimo local de $f(x)$ si $f(c)$ es menor que los valores de $f(x)$ en todos los puntos cercanos a $(c)$.
#
# **Máximos y Mínimos Absolutos (Globales)**
#
# - **Máximo Absoluto**: Un punto $(x = c)$ es un máximo absoluto de $f(x)$ en un intervalo si $f(c)$ es el mayor valor que $f(x)$ alcanza en ese intervalo.
#
# - **Mínimo Absoluto**: Un punto $(x = c)$ es un mínimo absoluto de $f(x)$ en un intervalo si $f(c)$ es el menor valor que $f(x)$ alcanza en ese intervalo.
#
# **Métodos para Encontrar Máximos y Mínimos**
#
# **Test de la Primera Derivada**
#
#    - Si $f'(x)$ cambia de positivo a negativo en $(x = c)$, entonces $f(c)$ es un máximo local.
#
#    - Si $f'(x)$ cambia de negativo a positivo en $(x = c)$, entonces $f(c)$ es un mínimo local.
#
# **Test de la Segunda Derivada**
#
#    - Si $f''(c) > 0$, entonces $f(c)$ es un mínimo local (concavidad hacia arriba).
#
#    - Si $f''(c) < 0$, entonces $f(c)$ es un máximo local (concavidad hacia abajo).
#
# **Ejemplo Práctico: Análisis de $f(x) = x^3 - 3x^2 + 4$**
#
# Vamos a determinar los máximos y mínimos de esta función, tanto locales como absolutos.
#
# **Función**:
#
# $f(x) = x^3 - 3x^2 + 4$
#
# **Derivadas**:
#
# - **Primera Derivada**:
#
#   $f'(x) = 3x^2 - 6x$
#
# - **Segunda Derivada**:
#
#   $f''(x) = 6x - 6$
#
# **Encontrar Puntos Críticos**:
#
# $f'(x) = 0 \rightarrow 3x^2 - 6x = 0 \rightarrow x(x-2) = 0 \rightarrow x = 0, \; x = 2$
#
# **Visualización con Python**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir la función y sus derivadas
def f(x):
    return x**3 - 3*x**2 + 4

def df(x):
    return 3*x**2 - 6*x

def ddf(x):
    return 6*x - 6

# Generar valores de x
x_values = np.linspace(-1, 3, 400)
y_values = f(x_values)
df_values = df(x_values)
ddf_values = ddf(x_values)

# Crear gráfico
plt.figure(figsize=(12, 7))
plt.plot(x_values, y_values, label='f(x) = $x^3 - 3x^2 + 4$', color='navy', linestyle='-', linewidth=2)
plt.plot(x_values, df_values, label="f'(x) = $3x^2 - 6x$", color='darkred', linestyle='--', linewidth=2)
plt.plot(x_values, ddf_values, label="f''(x) = $6x - 6$", color='darkgreen', linestyle=':', linewidth=2)
plt.axhline(0, color='grey', linewidth=0.5)
plt.axvline(0, color='grey', linewidth=0.5)
plt.title('Análisis de Máximos, Mínimos y Puntos de Inflexión', fontsize=14, fontweight='bold')
plt.xlabel('x', fontsize=12)
plt.ylabel('f(x)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(frameon=True, loc='best', shadow=True)
plt.show()

# %% [markdown]
# **Interpretación**
#
# - **Función $f(x)$**: Muestra el comportamiento de la función. Observamos posibles máximos y mínimos en $(x = 0)$ y $(x = 2)$.
#
# - **Primera Derivada $f'(x)$**: Las raíces de $f'(x)$ indican los puntos donde la función puede tener máximos o mínimos. La derivada también muestra dónde la función es creciente o decreciente.
#
# - **Segunda Derivada $f''(x)$**: Ayuda a confirmar si los puntos críticos son máximos o mínimos según la concavidad indicada por la segunda derivada.
#
# Este análisis proporciona una visión completa de cómo los métodos de derivadas pueden ser utilizados para identificar características críticas de la función, facilitando la optimización y otros análisis importantes en diversas aplicaciones.

# %% [markdown]
# ### **6.1.2 Aplicaciones de máximos y mínimos**

# %% [markdown]
# Las aplicaciones de máximos y mínimos en matemáticas son vastas y cruciales en una multitud de campos como la economía, ingeniería, física, y más. Estos conceptos se utilizan para optimizar soluciones y resolver problemas prácticos en los que se busca maximizar o minimizar alguna cantidad. Aquí, exploraremos cómo se utilizan los máximos y mínimos para resolver problemas prácticos con un enfoque en un ejemplo específico.
#
# **Ejemplo Práctico: Maximización del Área**
#
# Supongamos que necesitas construir un corral rectangular que esté pegado a un edificio, utilizando el edificio como uno de los lados del corral. Dispones de 100 metros de valla para los otros tres lados del corral. ¿Cuál es la mayor área que puedes encerrar?
#
# **Descripción del problema**:
#
# - **Perímetro disponible para tres lados**: 100 metros.
#
# - **Variables**:
#
#   - $(x)$: los dos lados del corral que son paralelos al edificio.
#
#   - $(y)$: el lado del corral perpendicual al edificio (solo se necesita una valla para este lado).
#
# **Relación de Perímetro**:
#
# $2x + y = 100$
#
# **Área a Maximizar**:
#
# $A = x \times y$
#
# **Formulación Matemática**
#
# Primero, expresamos $(y)$ en términos de $(x)$ usando la restricción del perímetro:
#
# $y = 100 - 2x$
#
# Sustituir en la fórmula del área:
#
# $A(x) = x(100 - 2x) = 100x - 2x^2$
#
# **Derivación para Encontrar Máximos**
#
# Para maximizar el área, derivamos $A(x)$ respecto a $(x)$ y encontramos los puntos críticos:
#
# $A'(x) = 100 - 4x$
#
# Igualamos a cero para encontrar los puntos críticos:
#
# $100 - 4x = 0$
#
# $x = 25 \, \text{metros}$
#
# Calculamos $(y)$ cuando $(x = 25)$:
#
# $y = 100 - 2(25) = 50 \, \text{metros}$
#
# **Segunda Derivada para Confirmar Máximo**
#
# $A''(x) = -4$
#
# Dado que $A''(x) < 0$, hay un máximo local en $(x = 25)$.
#
# **Visualización con Python**

# %%
import numpy as np
import matplotlib.pyplot as plt

def A(x):
    return 100*x - 2*x**2

x_values = np.linspace(0, 50, 400)
A_values = A(x_values)

# Punto máximo
x_max = 25
A_max = A(x_max)

plt.figure(figsize=(14, 8))
plt.plot(x_values, A_values, label='Área $A(x) = 100x - 2x^2$', color='darkblue', linewidth=2)
plt.scatter(x_max, A_max, color='red', s=50, zorder=5)  # Máximo más visible
plt.title('Maximización del Área del Corral', fontsize=16, fontweight='bold')
plt.xlabel('Longitud del lado x (m)', fontsize=14)
plt.ylabel('Área (m²)', fontsize=14)
plt.axvline(x=x_max, color='grey', linestyle='--', label=f'Máximo en x={x_max}m')
plt.axhline(y=A_max, color='grey', linestyle='--', label=f'Área máxima={A_max} m²')
plt.annotate('Punto máximo', xy=(x_max, A_max), xytext=(30, 100),
             textcoords='offset points', ha='center',
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.5', color='black'))
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(loc='upper right', frameon=True, shadow=True, fontsize=12)
plt.subplots_adjust(top=0.9, bottom=0.1, left=0.1, right=0.9)  # Ajustar manualmente los márgenes
plt.show()

# %% [markdown]
# **Interpretación**
#
# - **Gráfico Azul**: Representa cómo cambia el área del corral en función de la longitud de $(x)$, los lados paralelos al edificio.
#
# - **Punto Rojo**: Indica el valor de $(x)$ que maximiza el área, que es 25 metros, dando un área máxima de 1250 metros cuadrados.
#
# Este ejemplo ilustra cómo se pueden utilizar conceptos de cálculo para resolver problemas prácticos de optimización. Los máximos y mínimos son fundamentales para diseñar soluciones eficientes y económicas en situaciones reales.

# %% [markdown]
# ### **6.1.3 Graficar utilizando máximos y mínimos**

# %% [markdown]
# Graficar una función utilizando máximos y mínimos es una técnica muy útil para visualizar y entender el comportamiento de la función a lo largo de su dominio. Identificar los puntos donde una función alcanza sus valores máximos y mínimos locales y absolutos nos ayuda a interpretar gráficamente la función de manera efectiva.
#
# **Conceptos Clave**
#
# Antes de graficar, es fundamental identificar estos elementos:
#
# **Máximos y Mínimos Locales**: Puntos donde la función alcanza valores locales extremos.
#
# **Puntos Críticos**: Puntos donde la primera derivada $f'(x)$ es cero o no está definida. Estos puntos son candidatos para ser máximos o mínimos locales.
#
# **Concavidad y Puntos de Inflexión**: Utilizar la segunda derivada $f''(x)$ para determinar la concavidad (hacia arriba o hacia abajo) y localizar puntos de inflexión.
#
# **Ejemplo Práctico: Función Cuadrática**
#
# Vamos a tomar una función cuadrática simple para ilustrar cómo graficarla utilizando su máximo local.
#
# **Función**:
#
# $f(x) = -x^2 + 4x - 3$
#
# **Derivadas y Análisis**
#
# - **Primera Derivada** (para encontrar puntos críticos):
#
#   $f'(x) = -2x + 4$
#
#   Igualando a cero para encontrar puntos críticos:
#
#   $-2x + 4 = 0 \rightarrow x = 2$
#
# - **Segunda Derivada** (para determinar la concavidad):
#
#   $f''(x) = -2$
#
#   Ya que $f''(x) < 0$ para todo $(x)$, la función es cóncava hacia abajo en todo su dominio, lo que implica que el punto crítico $(x = 2)$ es un máximo local.
#
# **Valor del Máximo**
#
# $f(2) = -(2)^2 + 4(2) - 3 = 1$
#
# El máximo local está en $(2, 1)$.
#
# **Visualización con Python**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir la función
def f(x):
    return -x**2 + 4*x - 3

# Generar valores de x
x_values = np.linspace(0, 4, 400)
y_values = f(x_values)

# Punto de máximo local
x_max = 2
y_max = f(x_max)

plt.figure(figsize=(10, 6))
plt.plot(x_values, y_values, label='$f(x) = -x^2 + 4x - 3$', color='navy', linewidth=2)
plt.scatter(x_max, y_max, color='darkred', s=50, zorder=5, label='Máximo Local $(2, 1)$')  # Máximo más visible
plt.title('Gráfica de la Función Cuadrática', fontsize=16, fontweight='bold')
plt.xlabel('x', fontsize=14)
plt.ylabel('f(x)', fontsize=14)
plt.axvline(x=x_max, color='grey', linestyle='--', linewidth=1.5, label=f'x={x_max}')
plt.axhline(y=y_max, color='grey', linestyle='--', linewidth=1.5, label=f'f(x)={y_max}')
plt.annotate('Punto máximo', xy=(x_max, y_max), xytext=(3, 5),
             textcoords='offset points', ha='center',
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=.5', color='black'))
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(loc='upper right', frameon=True, shadow=True, fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretación de la Gráfica**
#
# - **Curva Azul**: Representa la función cuadrática $f(x)$. Esta curva muestra claramente el comportamiento de la función y su punto máximo.
#
# - **Punto Rojo**: Indica el máximo local en $(2, 1)$, que es el punto más alto en la gráfica debido a que la función es cóncava hacia abajo en todo su dominio.
#
# Este tipo de visualización es fundamental para entender completamente el comportamiento de funciones matemáticas complejas y para aplicaciones prácticas en optimización, ingeniería y ciencias económicas.

# %% [markdown]
# ### **6.1.4 Tasa de cambio**

# %% [markdown]
# La **tasa de cambio** es un concepto fundamental en cálculo y otras áreas de las matemáticas, que describe cómo varía una cantidad en relación con otra. En el contexto del cálculo diferencial, la tasa de cambio es esencialmente la derivada de una función y proporciona información crucial sobre la velocidad a la que una variable cambia con respecto a otra.
#
# **Conceptos de Tasa de Cambio**
#
# **Tasa de Cambio Promedio**: Es la tasa a la que cambia una cantidad en relación con otra a lo largo de un intervalo. Se calcula como el cociente de los cambios en las variables.
#
#    $\text{Tasa de cambio promedio} = \frac{\Delta y}{\Delta x} = \frac{f(b) - f(a)}{b - a}$
#
#    donde $f(x)$ es la función, y $(a)$ y $(b)$ son dos puntos en el dominio de $(f)$.
#
# **Tasa de Cambio Instantánea**: Es la velocidad instantánea con la que cambia una variable respecto a otra en un punto específico, y se define como la derivada de la función en ese punto.
#
#    $\text{Tasa de cambio instantánea en } x = a = f'(a) = \lim_{h \to 0} \frac{f(a+h) - f(a)}{h}$
#
# **Ejemplo Práctico: Velocidad de un Automóvil**
#
# Supongamos que la posición $s(t)$ de un automóvil que se mueve a lo largo de una carretera recta está dada por la función $s(t) = t^2 + 2t$ donde $(s)$ está en metros y $(t)$ en segundos.
#
# **Tasa de Cambio Promedio entre 2 segundos y 5 segundos**
#
# $\text{Tasa de cambio promedio} = \frac{s(5) - s(2)}{5 - 2}$
#
# Calculamos $s(5)$ y $s(2)$:
#
# $s(5) = 5^2 + 2 \times 5 = 25 + 10 = 35 \, \text{m}$
#
# $s(2) = 2^2 + 2 \times 2 = 4 + 4 = 8 \, \text{m}$
#
# $\text{Tasa de cambio promedio} = \frac{35 - 8}{3} = \frac{27}{3} = 9 \, \text{m/s}$
#
# **Tasa de Cambio Instantánea en $(t = 3)$ segundos**
#
# Calculamos la derivada $s'(t)$:
#
# $s'(t) = 2t + 2$
#
# $s'(3) = 2 \times 3 + 2 = 8 \, \text{m/s}$
#
# **Visualización con Python**
#
# Vamos a visualizar la función de posición y su tasa de cambio (velocidad).

# %%
import numpy as np
import matplotlib.pyplot as plt

def s(t):
    return t**2 + 2*t

def ds(t):
    return 2*t + 2

# Generar valores de t
t_values = np.linspace(0, 6, 400)
s_values = s(t_values)
ds_values = ds(t_values)

plt.figure(figsize=(12, 8))

# Configurar el primer subplot para posición
plt.subplot(2, 1, 1)
plt.plot(t_values, s_values, label='Posición $s(t) = t^2 + 2t$', color='navy', linestyle='-', linewidth=2)
plt.title('Análisis de Movimiento del Automóvil', fontsize=16, fontweight='bold')
plt.xlabel('Tiempo (s)', fontsize=12)
plt.ylabel('Posición (m)', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(loc='upper left', frameon=True, shadow=True, fontsize=10)

# Configurar el segundo subplot para velocidad
plt.subplot(2, 1, 2)
plt.plot(t_values, ds_values, label='Velocidad $s\'(t) = 2t + 2$', color='crimson', linestyle='--', linewidth=2)
plt.xlabel('Tiempo (s)', fontsize=12)
plt.ylabel('Velocidad (m/s)', fontsize=12)
plt.axhline(0, color='gray', linewidth=0.5)
plt.axvline(0, color='gray', linewidth=0.5)
plt.grid(True, linestyle=':', alpha=0.5)
plt.legend(loc='upper left', frameon=True, shadow=True, fontsize=10)

plt.tight_layout(pad=3.0)
plt.show()

# %% [markdown]
# **Interpretación**
#
# - **Gráfico Superior (Azul)**: Representa la posición del automóvil en función del tiempo, mostrando cómo la distancia aumenta con el tiempo.
#
# - **Gráfico Inferior (Rojo)**: Muestra la velocidad del automóvil, que es la tasa de cambio instantánea de su posición, también en función del tiempo.
#
# Este enfoque nos permite comprender visualmente cómo cambia la posición y la velocidad del automóvil a lo largo del tiempo, ilustrando la aplicación de las tasas de cambio en problemas prácticos de movimiento.

# %% [markdown]
# ### **6.1.5 Encontrar máximos y mínimos**

# %% [markdown]
# Encontrar máximos y mínimos de una función es un proceso crucial en cálculo y aplicaciones matemáticas, especialmente cuando se trata de optimización. Los máximos y mínimos pueden ser locales, es decir, los más altos o bajos en una pequeña región, o globales, los más altos o bajos en todo el dominio de la función.
#
# **Conceptos Clave**
#
# **Máximo Local**: Un punto $(x=c)$ es un máximo local de $f(x)$ si $f(c)$ es mayor que todos los valores de $f(x)$ cerca de $(c)$.
#
# **Mínimo Local**: Un punto $(x=c)$ es un mínimo local de $f(x)$ si $f(c)$ es menor que todos los valores de $f(x)$ cerca de $(c)$.
#
# **Máximo Absoluto**: El valor más alto que $f(x)$ alcanza en su dominio.
#
# **Mínimo Absoluto**: El valor más bajo que $f(x)$ alcanza en su dominio.
#
# **Método para Encontrar Máximos y Mínimos**
#
# **Primera Derivada**:
#
#    - Encuentra la primera derivada $f'(x)$.
#
#    - Resuelve $f'(x) = 0$ para encontrar los puntos críticos.
#
#    - Estos puntos son candidatos para ser máximos o mínimos locales.
#
# **Segunda Derivada (Test de Concavidad)**:
#
#    - Calcula la segunda derivada $f''(x)$.
#
#    - Si $f''(x) > 0$ en un punto crítico, entonces es un mínimo local (cóncava hacia arriba).
#
#    - Si $f''(x) < 0$ en un punto crítico, entonces es un máximo local (cóncava hacia abajo).
#
# **Ejemplo: Análisis de $f(x) = x^3 - 6x^2 + 9x + 1$**
#
# **Cálculo de Derivadas**
#
# - **Primera Derivada**:
#
#   $f'(x) = 3x^2 - 12x + 9$
#
# - **Segunda Derivada**:
#
#   $f''(x) = 6x - 12$
#
# **Encontrar Puntos Críticos**
#
# - Resolver $f'(x) = 0$:
#
#   $3x^2 - 12x + 9 = 0$
#
#   $x = 1, \; x = 3 \; \text{(usando la fórmula cuadrática)}$
#
# **Test de Concavidad**
#
# - Evaluar $f''(x)$ en $(x = 1)$ y $(x = 3)$:
#
#   $f''(1) = 6(1) - 12 = -6 \; (\text{máximo local})$
#
#   $f''(3) = 6(3) - 12 = 6 \; (\text{mínimo local})$
#
# **Visualización con Python**
#
# Vamos a graficar la función y sus puntos críticos para visualizar estos máximos y mínimos.

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return x**3 - 6*x**2 + 9*x + 1

def df(x):
    return 3*x**2 - 12*x + 9

def ddf(x):
    return 6*x - 12

x_values = np.linspace(-1, 5, 400)
y_values = f(x_values)

# Puntos críticos
critical_points = [1, 3]
critical_values = [f(x) for x in critical_points]

plt.figure(figsize=(12, 7))
plt.plot(x_values, y_values, label='$f(x) = x^3 - 6x^2 + 9x + 1$', color='navy', linewidth=2)
plt.scatter(critical_points, critical_values, color='darkred', s=50, label='Puntos Críticos')
plt.title('Análisis de Máximos y Mínimos en Función Polinómica', fontsize=16, fontweight='bold')
plt.xlabel('x', fontsize=14)
plt.ylabel('f(x)', fontsize=14)
plt.axhline(0, color='gray', linewidth=0.5)
plt.axvline(0, color='gray', linewidth=0.5)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend(loc='upper right', frameon=True, shadow=True)
for x, y in zip(critical_points, critical_values):
    plt.annotate(f'({x}, {y})', xy=(x, y), xytext=(10, -20), textcoords='offset points')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Interpretación**
#
# - **Gráfico Azul**: Muestra la función con su forma polinómica típica, ascendiendo y descendiendo en el dominio dado.
#
# - **Puntos Rojos**: Indican los máximos y mínimos locales encontrados a través del análisis de derivadas. Aquí, $(x = 1)$ es un máximo local debido a que la función es cóncava hacia abajo, y $(x = 3)$ es un mínimo local porque la función es cóncava hacia arriba en esos puntos.
#
# Este enfoque detallado de encontrar máximos y mínimos es esencial para entender el comportamiento de funciones en ciencias, ingeniería, economía, y más.

# %% [markdown]
# | **Inicio** | **atrás 5** |
# |----------- |-------------- |
# | [🏠](../../README.md) | [⏪](./05_Algebra_y_calculo_diferencial_para_la_ciencia_de_datos.ipynb)|
